# Package Parts (e1d43c7b-7f48-4791-9f56-88c6d5332ab2)
# Package Performances (e30e9116-97d5-4b17-93ab-c2191de2ff7b)
# Package Ports (667a82af-ceeb-49e9-b967-7f5fcbd598e9)
# Package Quantities (bb76d718-ce1d-4764-b594-7eac84ef616d)
# Package QuantityCalculations (edbca376-28af-410b-a6d1-79de3ed30958)
# Package RationalFunctions (a5c43ddc-c041-46b5-876d-3b40763ee7e7)
# Package RealFunctions (81c46927-bc2c-44bc-9824-3874edd5dc7a)
# Package Requirements (7337e415-092b-49c9-9224-360fd4de3fe0)
# Package ScalarFunctions (271418fd-bb00-406d-b774-ea35a3d6c657)
# Package ScalarValues (03b93b69-fb6f-47fe-9cad-572b24a2caf7)
# Package SequenceFunctions (677f2119-f63b-4571-837b-27d643447bdb)
# Package SI (7a977073-b142-484f-a886-294a70a7a6d5)
# Package SIPrefixes (5c6f33de-dab7-47e7-a424-ab1c00997d05)
# Package StatePerformances (5f0f157f-3db7-437f-a6ed-434b0a27585f)
# Package States (e0816fa7-e908-40dd-a217-72744d116aa2)
# Package StateSpaceRepresentation (8a6f3803-af6a-465e-ad85-bf73ee3ffd46)
# Package StringFunctions (47952d17-3265-4177-b0b6-2dcc8b33570e)
# Package SysML (d1669d92-6d7c-45b9-aea6-127dd85becd5)
# Package Time (4a47877e-45c3-4054-addb-5717484525e6)
# Package TradeStudies (43e01651-f31b-4f45-99e3-d2198071fde9)
# Package Transfers (11140ef0-a18e-45b6-908f-640d2c5fb65e)
# Package TransitionPerformances (10f6855a-681d-46e4-a34c-33289782c53b)
# Package UnitsAndScales (01893f32-06a2-49e8-9fa5-ea86dc79d147)
# Package UnlimitedNaturalFunctions (f47306b5-aacb-47bb-b8e0-8df8f38c100e)
# Package USCustomaryUnits (24e9186b-523a-41ae-8800-5951568aac59)
# Package VerificationCases (abaedc62-dd0f-4018-ae01-5798bed3a2b2)
# Package Views (072379db-7cee-49ec-82ab-b8953178c784)

# %% [markdown]
# ### Limited querying is also possible.
#
# The query string works as an ["import"](https://github.com/Systems-Modeling/SysML-v2-Pilot-Implementation/blob/0be3bc228ad3cc56bfb9c340866c2ae59a6d2601/org.omg.sysml.interactive/src/org/omg/sysml/interactive/SysMLInteractive.java#L230) statement in Sysml. That is the following is to be intrepreted as `import Objects::*;` and then show all membership. The [specs](/files/doc/2-OMG_Systems_Modeling_Language_%28SysML%29.pdf) (page 108 of 413) provide an overview what can be passed to import. (If specs link doesn't work, [use this absolute link](https://github.com/Systems-Modeling/SysML-v2-Release/blob/master/doc/2-OMG_Systems_Modeling_Language_%28SysML%29.pdf))

# %%
%list "Objects::*"
# Out:
# AssociationStructure BinaryLinkObject (1bd31497-c09c-43fd-954e-20b2bd55b5ed)
# Feature binaryLinkObjects (06e72ef0-b892-493f-b6c6-0f3b15cb7f7d)
# AssociationStructure LinkObject (1985185c-fe05-4548-b7a4-b9779a17f338)
# Feature linkObjects (5bd0c22f-e596-468d-ac1e-e62d59770944)
# Structure Object (e2846610-dfb0-4714-aa82-61da2c326c8f)
# Feature objects (6c32581f-2492-47fe-a84c-b9559d26c797)

# %%
%list "Objects::**"
# Out:
# Feature $collection (bd3515d0-0a19-4621-ae89-4f8bd770f28e)
# AssociationStructure BinaryLinkObject (1bd31497-c09c-43fd-954e-20b2bd55b5ed)
# Feature binaryLinkObjects (06e72ef0-b892-493f-b6c6-0f3b15cb7f7d)
# Step enactedPerformances (ad8cb27d-df4a-4831-bb42-3adec40614d6)
# Feature incomingTransfers (343d8864-88f8-421b-a57c-c6f614689b25)
# Feature incomingTransfersToSelf (95d1e92b-e154-43a3-a2e1-21878beabc83)
# BindingConnector instant (dec71e8c-f15d-46bc-bad9-a767e2ef8c40)
# Feature involvedObjects (b3d1a80f-48b7-43f3-aa89-8f0470eb13ac)
# Step involvingPerformances (c09ba9a7-386d-4f68-8a86-2ff395504b95)
# Feature isInstant (75dabbf5-2aa3-4184-9414-27b80b4e5251)
# Feature isMove (8d2d3b7e-315c-4f35-98e2-b5744ff050a1)
# Feature isPush (562948a0-d0c3-4e5e-a809-39a6008766c2)
# Feature item (c320c55b-a69c-4458-9a47-e83c0b119289)
# AssociationStructure LinkObject (1985185c-fe05-4548-b7a4-b9779a17f338)
# Feature linkObjects (5bd0c22f-e596-468d-ac1e-e62d59770944)
# Feature longerOccurrence (7dfe9f92-334c-4d16-a8ed-6dec7faf1fd8)
# Feature middleShots (43294e41-e5f4-4495-9e63-4c81fffac406)
# Connector moving (bbf6805e-aaf2-4d15-a9a7-1cfc8c26604d)
# Structure Object (e2846610-dfb0-4714-aa82-61da2c326c8f)
# Feature objects (6c32581f-2492-47fe-a84c-b9559d26c797)
# Package Objects (9e80cbce-03ba-435a-bdd7-93086560a138)
# Feature outgoingTransfers (d423c488-004b-4eff-95be-c7391116b657)
# Feature outgoingTransfersFromSelf (79f5b966-2b21-4527-9a57-624364b65774)
# Feature participant (b735bde2-2139-41a4-a21f-39958da836e0)
# Feature performers (692cbc81-e9b6-492b-87f7-6be5a40eda03)
# Feature portionOf (bb13115d-7905-47dc-8d4d-8352d55b3604)
# Feature portionOfLife (3c2d3a6a-ac44-449e-ae93-127e8963433f)
# Feature portions (3fa3545c-3797-4044-bee5-360d9691a388)
# Feature predecessors (ace25691-1475-4da3-899e-21badbbff61b)
# Connector pushing (79f44f7d-30aa-401d-ad3b-f48edd6b2663)
# Feature s (3eb6abbf-3c58-4c3f-9d25-d41af7b4c1a7)
# Feature shorterOccurrence (42eb25f9-b3c2-4c21-a4d7-f6b062480344)
# Feature snapshotOf (0302583b-d477-4908-a01d-3883de85b94e)
# Feature snapshots (9f798afb-e882-4997-88b2-971a7c773039)
# Feature sourceOutput (14ff448b-d94e-49a1-8530-0acb44c95116)
# AssociationStructure SourceOutputLink (fd653553-b751-4586-9977-544992793a72)
# Connector sourceOutputLink (5c19e242-1240-4d40-bc4c-6b3c8f71fad8)
# Expression subBooleanEvaluations (c9df4e01-956a-4b9e-a822-92d776502a89)
# Expression subevaluations (8f2eae28-9739-455e-9ec4-7e183059e943)
# Step subflows (68a58002-e0e9-47b3-8eed-962a9b8700cf)
# Feature suboccurrences (b61b65a3-e6a8-4c33-9a29-49e5644717d1)
# Step subperformances (698beeb7-32df-4564-b22c-be9d64b76d55)
# Step subtransfers (edb11c6d-c871-4d96-ac4e-577d666fdf1f)
# Feature successors (bc1ac9c3-16d5-484c-b953-887ee9473e99)
# Feature targetInput (510aeeee-5d9d-4167-82ed-e9888219f21e)
# AssociationStructure TargetInputLink (80bd07c0-dfc2-40aa-b7c8-35979b37e85c)
# Connector targetInputLink (47ed0fd7-87d3-4262-bf8d-ea748ce8839d)
# Feature timeSliceOf (31a5b665-d7d7-495e-a065-e94e6722ff76)
# Feature timeSlices (7d5c5528-72c7-4c2a-a3df-b6478517f9e7)

# %% [markdown]
# It is also possible to have a filter condition %list namespace::**[filterCondition]

# %% [markdown]
# ## viz
#
# Graphviz'ify elements from the model.
#
# [Codebase](https://github.com/Systems-Modeling/SysML-v2-Pilot-Implementation/blob/master/org.omg.sysml.jupyter.kernel/src/main/java/org/omg/sysml/jupyter/kernel/magic/Viz.java) and [Kernel Code](https://github.com/Systems-Modeling/SysML-v2-Pilot-Implementation/blob/0be3bc228ad3cc56bfb9c340866c2ae59a6d2601/org.omg.sysml.interactive/src/org/omg/sysml/interactive/SysMLInteractive.java#L283-L316)
#
# Viz supports '-h' option for displaying some help:

# %%
%viz -h
# Out:
# Usage: %viz [--view=<VIEW>] [--style=<STYLE>...] <NAME> [<NAME>...]
#
# Visualize model elements of <NAME>(s). <NAME>s must be fully qualified.
#
# <VIEW> is case insensitive and possible candidates are:
#    DEFAULT		Automatically choose an appropriate view from the given model element names
#    TREE			Show a tree-structural view, like a Block Definition Diagram (BDD)
#    INTERCONNECTION	Show an interconnection view, like an Internal Block Diagram (IBD)
#    STATE		Show state machines
#    ACTION		Show actions like an activity diagram
#    MIXED		Show multiple views
#
# <STYLE> is also case insensitive. Multiple --style options are allowed.  The possible style names are:
#    DEFAULT		Standard B&W format
#    STDCOLOR		Standard format with colors
#    PLANTUML		PlantUML format
#    PUMLCODE		Show PlantUML code mainly for debugging
#    TB			Top-to-Bottom orientation
#    LR			Left-to-Right orientation
#    POLYLINE		Polyline style
#    ORTHOLINE		Orthogonal line style
#    COMPTREE		Show tree structures in compartments

# %% [markdown]
# Generating a graph:

# %%
%viz "VerificationCases"

# %%
%viz "Objects" --style="PLANTUML"

# %% [markdown]
# ### Arguments to %viz
#
# - style : COMPTREE, POLYLINE, LR, STDCOLOR, PLANTUML, DEFAULT, TB, ORTHOLINE
# - view : Default Tree State Interconnection Action Sequence MIXED

# %%
%viz "Objects" --view=State --style="PLANTUML"

# %% [markdown]
# ### %viz Hidden Option
#
# There is also a hidden style option: `PUMLCODE` to get the original plant UML code of the diagram.

# %%
%viz --style=PUMLCODE Views
# Out:
# @startuml
# skinparam monochrome true
# skinparam classbackgroundcolor white
# skinparam shadowing false
# skinparam wrapWidth 300
# hide circle
#
# note as E1
# [[psysml:9b2bf20d-29ec-4c21-85b1-59bede893568 @]]Ports that are on this Part.
#
# end note
# rec usage "exhibitedStates" as E3 [[psysml:5499f82c-b1d3-4ea7-afbf-2a8dbcc7983f ]] {
# }
#
# note as E2
# [[psysml:060caad2-fc28-40bc-a6e5-3e21683329bd @]]Actions that are performed by this Part.
#
# end note
# note as E4
# [[psysml:6095cc99-40aa-42bd-9956-22cd8b6f744f @]]States that are exhibited by this Part.
#
# end note
# E4 .. E3 [[psysml:6095cc99-40aa-42bd-9956-22cd8b6f744f ]]
# note as E5
# [[psysml:abde3b6e-3afd-4802-bf33-055e71b9267d @]]The entity that is being checked for satisfaction of the required constraints.
#
# end note
# note as E6
# [[psysml:09c12d5c-d62a-4381-84d5-a6ee43db674f @]]Note: assumptions and constraints are redefined here solely to simplify the
# resolution of their qualified names as library elements.
#
# end note
# note as E7
# [[psysml:fa2eb228-b253-41d4-865a-61cca008e66c @]]Nested requirements, which are also required constraints.
#
# end note
# note as E8
# [[psysml:8463d37d-97cc-48ad-9b59-d421b35c38ae @]]The checks of any concerns being addressed (as required constraints).
#
# end note
# note as E9
# [[psysml:26a95237-1abd-4b54-a096-3c7d819011c8 @]]Other Views that are used in the rendering of this View.
#
# end note
# note as E10
# [[psysml:8074b928-c9b1-4292-b395-5bc41cfb257f @]]The rendering of this View.
#
# end note
# note as E11
# [[psysml:0f266267-6b33-451f-ac75-0e401ed04368 @]]Checks that the View satisfies all required ViewpointsUsages.
#
# end note
# note as E12
# [[psysml:8e677db8-b6f0-45e7-8df1-fbae93ae014f @]]The required ViewpointChecks.
# end note
# note as E13
# [[psysml:e1a2a478-c7d3-41dc-89e3-f22e928427fc @]]An assertion that all viewpointSatisfactions are true.
#
# end note
# note as E14
# [[psysml:e857bf8f-64cc-43da-8be7-07f535cb7b3a @]]ViewpointCheck is a RequirementCheck for checking if a View meets the concerns of viewpoint stakeholders.
# It is the base type of all ViewpointDefinitions.
#
# end note
# note as E15
# [[psysml:009b0ecc-ca1a-4d68-8885-513e3b9823c8 @]]Other Renderings used to carry out this Rendering.
#
# end note
# note as E16
# [[psysml:dd1381ed-06a9-4ca9-8770-b5b153a9d36c @]]Rendering is the base type of all RenderingDefinitions.
#
# end note
# note as E17
# [[psysml:70ee07d3-e90d-4e9f-a559-f03ab238c56f @]]A TextualRendering is a Rendering of a View into a textual format.
#
# end note
# note as E18
# [[psysml:56dd951a-163e-4f2c-a560-5223171e4d6d @]]A GraphicalRendering is a Rendering of a View into a Graphical format.
#
# end note
# note as E19
# [[psysml:08b5df83-6c54-4464-a421-b3c3b014d030 @]]A TabularRendering is a Rendering of a View into a tabular format.
#
# end note
# note as E20
# [[psysml:0a523d2f-3359-4165-b9a6-212b7dcff04b @]]views is the base feature of all ViewUsages.
#
# end note
# note as E21
# [[psysml:f013c5ff-597a-47ef-ad55-52ce20d59164 @]]viewpointChecks is the base feature of all ViewpointUsages.
#
# end note
# note as E22
# [[psysml:2b721f71-692a-4627-979b-00d4e2414502 @]]renderings is the base feature of all RenderingUsages.
#
# end note
# note as E23
# [[psysml:33292d64-448f-431a-9c02-87f2b3f590d3 @]]asTextualNotation renders a View into textual notation as defined in the
# KerML and SysML specifications.
#
# end note
# note as E24
# [[psysml:d2ebe7aa-f96b-4354-8856-a733c5f3d54e @]]asTreeDiagram renders a View as a tree diagram, using the
# graphical notation defined in the SysML specification.
#
# end note
# note as E25
# [[psysml:52deeb25-4fc5-4bb1-a7a1-88b1f3ec98b2 @]]asInterconnectionDiagram renders a View as an interconnection
# diagram, using the graphical notation defined in the SysML specification.
#
# end note
# note as E26
# [[psysml:f980431c-942e-4369-ae26-af5d4d1e1d3e @]]The Views to be rendered in the column cells, in order, of each rows of the table.
#
# end note
# note as E27
# [[psysml:7298ae0b-bacf-4dbe-9136-bb33c188fbf1 @]]asElementTable  renders a View as a table, with one row for each exposed
# Element and columns rendered by applying the columnViews in order to the
# Element in each row.
#
# end note
# @enduml

# %% [markdown]
# ## publish
#
# Push models to publish the model to a SysML v2 repository server.
#
# [Codebase](https://github.com/Systems-Modeling/SysML-v2-Pilot-Implementation/blob/master/org.omg.sysml.jupyter.kernel/src/main/java/org/omg/sysml/jupyter/kernel/magic/Publish.java)

# %%
%publish "Views"
# Out:
# ERROR:'Views' is a library element

# %% [markdown]
# So library elements can't be published, so we'll create a package and publish that.
#
# Package take from [MBSE4U Notebook](https://nbviewer.jupyter.org/github/MBSE4U/SysMLv2JupyterBook/blob/master/SysMLv2JupyterBook.ipynb).

# %%
package eVehicle_LogicalArchitecture_v1 {
    part eVehicle {    
        part body;
        part battery;
        part engine;
        part frontAxis;
        part rearAxis;
        part frontWheel[2];
        part rearWheel[2];
    }
}
# Out:
# Package eVehicle_LogicalArchitecture_v1 (9f38bf57-28ce-4b98-b071-7b9abb3e79da)

# %%
%publish eVehicle_LogicalArchitecture_v1
# Out:
# API base path: http://sysmlapiserver:9000
# Processing
# Posting Commit (29 elements)...
# 02d4d280-edde-4157-8ed9-1d0724a56339
# Saved to Project eVehicle_LogicalArchitecture_v1 Fri May 28 10:41:26 UTC 2021 (95ad44cd-a8bd-4b72-b246-e13fefc15893)

# %% [markdown]
# **Viewing Projects**
#
# Once the model has been published, we can view our stored [project](http://localhost:9000/projects) in the API server.

# %% [markdown]
# ## show
#
# Which gives a textual outline of the Model.
#
# [Codebase](https://github.com/Systems-Modeling/SysML-v2-Pilot-Implementation/blob/master/org.omg.sysml.jupyter.kernel/src/main/java/org/omg/sysml/jupyter/kernel/magic/Show.java)

# %%
%show Objects
# Out:
# Package Objects (9e80cbce-03ba-435a-bdd7-93086560a138)
#   [Membership Anything] Classifier Anything (21d7d06a-1cf9-4b1c-8a40-8834a437ab84)
#   [Membership things] Feature things (a25263f5-ea69-4556-89e9-7cd8b9435623)
#   [Import] Package Links (73bb3978-8fa6-4377-a973-4c04fa466d0d)
#   [Membership Occurrence] Class Occurrence (4708666b-538a-4082-9b55-eb1916ff660d)
#   [Membership Performance] Behavior Performance (f2f14b40-fc6e-4d79-8d54-99c8bfc42de5)
#   [Membership performances] Step performances (9cacbd80-de0a-40ee-9c88-1d61a444069d)
#   [Membership] Structure Object (e2846610-dfb0-4714-aa82-61da2c326c8f)
#     [Superclassing] Class Occurrence (4708666b-538a-4082-9b55-eb1916ff660d)
#     [FeatureMembership] Feature self (1b604c08-bf0a-41ad-928a-55cad3f398dd)
#       [FeatureTyping] Structure Object (e2846610-dfb0-4714-aa82-61da2c326c8f)
#       [Redefinition] Feature self (7fd42610-9bbc-4aca-a820-5d4d7c1acc7d)
#     [FeatureMembership] Step involvingPerformances (c09ba9a7-386d-4f68-8a86-2ff395504b95)
#       [FeatureTyping] Behavior Performance (f2f14b40-fc6e-4d79-8d54-99c8bfc42de5)
#       [Membership] MultiplicityRange (74e09deb-c193-4b5b-86cd-dfbedd9f352b)
#         [Subsetting (implicit)] Feature naturals (85758490-0027-4b04-a55f-433974bd21ce)
#         [Membership] LiteralInteger (dad934f9-0475-49d8-9cc0-87c76641a226)
#           [ReturnParameterMembership] Feature $result (1a77c918-5a3f-4401-b5c5-bf9f462dfeae)
