# Package Occurrences (5e055991-c3ee-47df-a218-de9a8f5c4ae6)
# Package Parts (887c3452-2ac3-4792-acea-6bc0711cc982)
# Package Performances (e96603e1-2b70-44c3-9707-b644798fd4e4)
# Package Ports (85b8dc01-029b-4170-9c06-7816243d9353)
# Package Quantities (bea05913-a277-49f1-a056-f2a977306728)
# Package QuantityCalculations (f9b4a66e-e696-4dda-ab04-2bf8b8a56afa)
# Package RationalFunctions (3312a3ce-0d24-456f-bb50-0554d535378c)
# Package RealFunctions (fc6e3e9b-8e85-418d-b7e6-d2e3a1ba2b5f)
# Package Requirements (cfefa313-d539-44c0-8684-c29add1e903a)
# Package ScalarFunctions (5f072626-3a66-428e-9a85-d7da00a8bb66)
# Package ScalarValues (8541fe3f-b0a4-4d81-b8b7-b5ccfc5a2736)
# Package SequenceFunctions (c6b7ff49-fbea-4977-baf6-21e384c2f1e0)
# Package SI (a57bb3cb-ee26-49f9-80be-e84d9a8e7946)
# Package SIPrefixes (51269929-90d7-4eda-8360-a44ef924fc85)
# Package StatePerformances (230cd944-8c98-4293-a8b9-fdf3eaf13706)
# Package States (cb30db8f-44ec-4d28-bfe1-1ff9bda15c25)
# Package StateSpaceRepresentation (641c5d74-568f-4da2-8063-62feecb76987)
# Package StringFunctions (70f0ed81-fa85-4929-bfc7-5d0ab9f75de3)
# Package SysML (e7f7125d-4c9f-4ea2-b771-459e6681f9a0)
# Package Time (8c63498e-6164-45be-8f51-1136a57f9702)
# Package TradeStudies (652c888e-fd7a-4eea-86b9-b8a3db467702)
# Package Transfers (14c64493-f1c5-4814-b200-d91f09f9e791)
# Package TransitionPerformances (52101e43-d345-4929-bf51-f248ccb3d831)
# Package UnitsAndScales (422530ab-3770-4498-8227-12f6f1deec1c)
# Package UnlimitedNaturalFunctions (eebe6faa-9996-4f0d-878b-0e15edeb23a2)
# Package USCustomaryUnits (b2a5725c-c8f4-42d0-b4a5-21147523c882)
# Package VectorCalculations (e1a33ba6-5e17-4fa5-bab6-b99c2bc5bff5)
# Package VerificationCases (80ddb95a-30ff-4483-a3cf-b3c13309b2b2)
# Package Views (acf76dc7-b5c7-43c8-8c4e-a717c37685f2)

# %% [markdown]
# ### Limited querying is also possible.
#
# The query string works as an ["import"](https://github.com/Systems-Modeling/SysML-v2-Pilot-Implementation/blob/0be3bc228ad3cc56bfb9c340866c2ae59a6d2601/org.omg.sysml.interactive/src/org/omg/sysml/interactive/SysMLInteractive.java#L230) statement in Sysml. That is the following is to be intrepreted as `import Objects::*;` and then show all membership. The [specs](/files/doc/2-OMG_Systems_Modeling_Language_%28SysML%29.pdf) (page 108 of 413) provide an overview what can be passed to import. (If specs link doesn't work, [use this absolute link](https://github.com/Systems-Modeling/SysML-v2-Release/blob/master/doc/2-OMG_Systems_Modeling_Language_%28SysML%29.pdf))

# %%
%list "Objects::*"
# Out:
# AssociationStructure BinaryLinkObject (06b2cd59-aeb2-4580-ba44-bd2eacc52d3e)
# Feature binaryLinkObjects (2e8d0b7c-9f00-4b14-b79b-8a524a2039e0)
# AssociationStructure LinkObject (78f33703-a255-4c80-bae4-f8dbd893a4be)
# Feature linkObjects (7c29e8a1-3ce7-4342-b137-18587999c278)
# Structure Object (36624b25-e374-41c3-8a4a-2c1e97bac4f3)
# Feature objects (f6be6d34-5511-4e8b-9539-b60cc9e1d954)

# %%
%list "Objects::**"
# Out:
# AssociationStructure BinaryLinkObject (06b2cd59-aeb2-4580-ba44-bd2eacc52d3e)
# Feature binaryLinkObjects (2e8d0b7c-9f00-4b14-b79b-8a524a2039e0)
# Step enactedPerformances (97ea439f-ad65-4c00-8860-7a8c3920dd0f)
# Feature endShot (e698a06e-5438-43fb-b139-058719fc8817)
# Feature incomingTransfers (94b3fdd2-5ed4-489d-a5b7-d873b0ecd1bb)
# Feature incomingTransfersToSelf (a893dea5-9996-4179-a0b5-66833cde6352)
# BindingConnector instant (2382be02-95e6-4247-b587-ed24300e0761)
# Feature involvedObjects (ead0a7c3-aabd-4b49-88c3-6036896785db)
# Step involvingPerformances (ffb7cea1-ca2a-4761-8cbc-e5330ecbe0cf)
# Feature isInstant (dbfe9474-5283-4400-99b2-74cb824ce98a)
# Feature isMove (6216f5ec-3ed5-4571-a840-78d81d602535)
# Feature isPush (d34fa53d-ac77-403c-8f39-7a90e5238364)
# Feature item (306e08bb-4cec-4c7f-9b8c-129b5f7e028d)
# AssociationStructure LinkObject (78f33703-a255-4c80-bae4-f8dbd893a4be)
# Feature linkObjects (7c29e8a1-3ce7-4342-b137-18587999c278)
# Feature longerOccurrence (55e44a01-ee90-42dc-9f14-d481a5efd12e)
# Feature middleShots (38bcb280-e7f4-462a-a415-61588a4cd927)
# Connector moving (c6be60a5-d03b-499a-bcbc-f323318472b3)
# Structure Object (36624b25-e374-41c3-8a4a-2c1e97bac4f3)
# Feature objects (f6be6d34-5511-4e8b-9539-b60cc9e1d954)
# Package Objects (9812ae5c-5cbf-476b-b6ce-96d3071717b0)
# Feature outgoingTransfers (dbd8e0ee-41a7-4788-918a-0032c4e60b48)
# Feature outgoingTransfersFromSelf (ad868fe7-34d8-4707-9a9d-2e31b50274a7)
# Feature participant (3281cfba-d517-40fa-898c-95fe5e2506d6)
# Feature performers (6cdbe7fc-72aa-47f1-9a2a-62ebc2c970a6)
# Feature portionOf (97bfbbfb-5e75-4a2a-880d-e1a871debb9b)
# Feature portionOfLife (0639d983-7ca1-439e-be86-47e30cbe6983)
# Feature portions (073449c5-ce11-491f-9350-0a69e7d7555e)
# Feature predecessors (1dc62538-2add-46dc-98a1-88b5204dec8f)
# Connector pushing (f2772755-5555-41c6-a9a2-ae76800f5fa5)
# Feature s (f1c5bff0-40e1-4fc9-ad30-662755a6923b)
# Feature sameLifeOccurrences (6ce0873a-b825-4787-b2b6-b8f73536843b)
# Feature shorterOccurrence (e1ddd290-6926-4063-868d-e915d738e15a)
# Feature snapshotOf (43dd7dc5-8e0e-4d58-8a7f-5ba7c3f080a0)
# Feature snapshots (74ad7ca5-2f8c-4dff-965c-59396963007a)
# Feature sourceOutput (4d6f461b-638a-44ca-b084-5620a9be8f97)
# AssociationStructure SourceOutputLink (1de08e6a-10a7-44c8-b98e-2344ecf16e91)
# Connector sourceOutputLink (1f189f6c-e509-40a6-8f82-4ce63b208604)
# Feature startShot (1c24f775-3169-4a17-a3ed-3f939bb01150)
# Expression subBooleanEvaluations (3c84e28d-529d-46ff-bf66-5b704334c285)
# Expression subevaluations (fc27b20b-8c5e-4366-9a71-6b34ef5cbd35)
# Feature suboccurrences (223bec19-f9de-4653-acec-3c1c671e018f)
# Step subperformances (4d729894-423f-4b11-bc0f-a84439fcefb2)
# Step subtransfers (32baccf7-b911-4d9f-a6e3-c80f08a4471c)
# Step subtransfersBefore (12e476dd-26f8-4aba-81a4-32bf4dfaf6ab)
# Feature successors (c949a1f6-2a60-4fe7-aa7b-f8c1c559bfd7)
# Feature targetInput (9b6752cc-e933-4d90-90e0-4082bcbeb2b1)
# AssociationStructure TargetInputLink (69143f23-57dc-4dad-902c-4433ba2343e0)
# Connector targetInputLink (57670640-22ce-4d5b-8b9c-82cebb5a81ef)
# Feature timeSliceOf (8e6e100d-a175-4aa9-9421-a7fd76005b23)
# Feature timeSlices (0791a052-8c0c-48be-bde5-4df4bbead736)

# %% [markdown]
# It is also possible to have a filter condition %list namespace::**[filterCondition]

# %% [markdown]
# ## viz
#
# Graphviz'ify elements from the model.
#
# [Codebase](https://github.com/Systems-Modeling/SysML-v2-Pilot-Implementation/blob/master/org.omg.sysml.jupyter.kernel/src/main/java/org/omg/sysml/jupyter/kernel/magic/Viz.java) and [Kernel Code](https://github.com/Systems-Modeling/SysML-v2-Pilot-Implementation/blob/0be3bc228ad3cc56bfb9c340866c2ae59a6d2601/org.omg.sysml.interactive/src/org/omg/sysml/interactive/SysMLInteractive.java#L283-L316)
#
# Viz supports '-h' option for displaying some help:

# %%
%viz -h
# Out:
# Usage: %viz [--view=<VIEW>] [--style=<STYLE>...] <NAME> [<NAME>...]
#
# Visualize model elements of <NAME>(s). <NAME>s must be fully qualified.
#
# <VIEW> is case insensitive and possible candidates are:
#    DEFAULT		Automatically choose an appropriate view from the given model element names
#    TREE			Show a tree-structural view, like a Block Definition Diagram (BDD)
#    INTERCONNECTION	Show an interconnection view, like an Internal Block Diagram (IBD)
#    STATE		Show state machines
#    ACTION		Show actions like an activity diagram
#    MIXED		Show multiple views
#
# <STYLE> is also case insensitive. Multiple --style options are allowed.  The possible style names are:
#    DEFAULT		Standard B&W format
#    STDCOLOR		Standard format with colors
#    PLANTUML		PlantUML format
#    PUMLCODE		Show PlantUML code mainly for debugging
#    TB			Top-to-Bottom orientation
#    LR			Left-to-Right orientation
#    POLYLINE		Polyline style
#    ORTHOLINE		Orthogonal line style
#    COMPTREE		Show tree structures in compartments

# %% [markdown]
# Generating a graph:

# %%
%viz "VerificationCases"

# %%
%viz "Objects" --style="PLANTUML"

# %% [markdown]
# ### Arguments to %viz
#
# - style : COMPTREE, POLYLINE, LR, STDCOLOR, PLANTUML, DEFAULT, TB, ORTHOLINE
# - view : Default Tree State Interconnection Action Sequence MIXED

# %%
%viz "Objects" --view=State --style="PLANTUML"

# %% [markdown]
# ### %viz Hidden Option
#
# There is also a hidden style option: `PUMLCODE` to get the original plant UML code of the diagram.

# %%
%viz --style=PUMLCODE Views
# Out:
# @startuml
# skinparam monochrome true
# skinparam classbackgroundcolor white
# skinparam shadowing false
# skinparam wrapWidth 300
# hide circle
#
# note as E1
# [[psysml:1c5fcd08-d9fd-49bc-a4e2-ae261d8c6448 @]]Ports that are on this Part.
#
# end note
# rec usage "exhibitedStates" as E3 [[psysml:8dbc8f6b-0343-4d33-99a8-5760419f94d8 ]] {
# }
#
# note as E2
# [[psysml:4e9067e2-a090-4395-a809-fee014ee4a04 @]]Actions that are performed by this Part.
#
# end note
# note as E4
# [[psysml:c776cd9a-5164-43a9-a94c-8f9cc5e9a948 @]]States that are exhibited by this Part.
#
# end note
# E4 .. E3 [[psysml:c776cd9a-5164-43a9-a94c-8f9cc5e9a948 ]]
# note as E5
# [[psysml:ec9376e5-4db4-40e5-bc50-b497fdf952e7 @]]The entity that is being checked for satisfaction of the required constraints.
#
# end note
# note as E6
# [[psysml:a6822d18-56b3-4fd0-8f62-782a4247584c @]]Note: assumptions and constraints are redefined here solely to simplify the
# resolution of their qualified names as library elements.
#
# end note
# note as E7
# [[psysml:c3529c04-d611-4216-b0f2-686b47059957 @]]Nested requirements, which are also required constraints.
#
# end note
# note as E8
# [[psysml:482449d9-c9ac-4aef-82b4-86b1947458ab @]]The checks of any concerns being addressed (as required constraints).
#
# end note
# note as E9
# [[psysml:fb04b049-9a43-46a4-bd9e-bd8cb92af303 @]]Other Views that are used in the rendering of this View.
#
# end note
# note as E10
# [[psysml:80f23535-e289-465e-acf7-95d7753ccd07 @]]The rendering of this View.
#
# end note
# note as E11
# [[psysml:80f6f2e5-de8d-4070-a963-a496488d3457 @]]Checks that the View satisfies all required ViewpointsUsages.
#
# end note
# note as E12
# [[psysml:90b00ba4-1cb0-4943-a119-a7e552382ecf @]]An assertion that all viewpointSatisfactions are true.
#
# end note
# note as E13
# [[psysml:36c41558-b0e1-4438-bc92-c492e3d975f9 @]]ViewpointCheck is a RequirementCheck for checking if a View meets the concerns of viewpoint stakeholders.
# It is the base type of all ViewpointDefinitions.
#
# end note
# note as E14
# [[psysml:22335571-a697-4503-ac29-f493b47ac11d @]]Other Renderings used to carry out this Rendering.
#
# end note
# note as E15
# [[psysml:377c2f23-9334-4e5b-93b8-3bdaa615e7af @]]Rendering is the base type of all RenderingDefinitions.
#
# end note
# note as E16
# [[psysml:1c9fe7a5-a9a1-41bf-8985-e554e304432b @]]A TextualRendering is a Rendering of a View into a textual format.
#
# end note
# note as E17
# [[psysml:8369fcac-a3de-4251-888c-04d8bc5a6bf0 @]]A GraphicalRendering is a Rendering of a View into a Graphical format.
#
# end note
# note as E18
# [[psysml:0d117136-ab9d-4f75-8ae5-6bfaa4d830f2 @]]A TabularRendering is a Rendering of a View into a tabular format.
#
# end note
# note as E19
# [[psysml:f5b09bf6-326a-4857-8484-afea9eeff438 @]]views is the base feature of all ViewUsages.
#
# end note
# note as E20
# [[psysml:d3dd153a-9382-41f3-9a9d-1d14384ead46 @]]viewpointChecks is the base feature of all ViewpointUsages.
#
# end note
# note as E21
# [[psysml:c08f5dc3-7492-49a7-b634-4e31a34b3eb8 @]]renderings is the base feature of all RenderingUsages.
#
# end note
# note as E22
# [[psysml:4e3986dd-f5a5-493c-94e2-d375a1eb9604 @]]asTextualNotation renders a View into textual notation as defined in the
# KerML and SysML specifications.
#
# end note
# note as E23
# [[psysml:b77e73d2-ec3b-473a-a9bc-f2ae5a6382dc @]]asTreeDiagram renders a View as a tree diagram, using the
# graphical notation defined in the SysML specification.
#
# end note
# note as E24
# [[psysml:c50b462d-478f-4ffe-983b-24725fd42435 @]]asInterconnectionDiagram renders a View as an interconnection
# diagram, using the graphical notation defined in the SysML specification.
#
# end note
# note as E25
# [[psysml:548467c7-bed8-40f8-ab56-243c0078e1c3 @]]The Views to be rendered in the column cells, in order, of each rows of the table.
#
# end note
# note as E26
# [[psysml:5b4ab46e-a64c-41a2-8b0b-a09f784e23de @]]asElementTable  renders a View as a table, with one row for each exposed
# Element and columns rendered by applying the columnViews in order to the
# Element in each row.
#
# end note
# @enduml

# %% [markdown]
# ## publish
#
# Push models to publish the model to a SysML v2 repository server.
#
# [Codebase](https://github.com/Systems-Modeling/SysML-v2-Pilot-Implementation/blob/master/org.omg.sysml.jupyter.kernel/src/main/java/org/omg/sysml/jupyter/kernel/magic/Publish.java)

# %%
%publish "Views"
# Out:
# ERROR:'Views' is a library element

# %% [markdown]
# So library elements can't be published, so we'll create a package and publish that.
#
# Package take from [MBSE4U Notebook](https://nbviewer.jupyter.org/github/MBSE4U/SysMLv2JupyterBook/blob/master/SysMLv2JupyterBook.ipynb).

# %%
package eVehicle_LogicalArchitecture_v1 {
    part eVehicle {    
        part body;
        part battery;
        part engine;
        part frontAxis;
        part rearAxis;
        part frontWheel[2];
        part rearWheel[2];
    }
}
# Out:
# Package eVehicle_LogicalArchitecture_v1 (0403ea01-5e6a-4f96-8b26-1ce67abc8377)

# %%
%publish eVehicle_LogicalArchitecture_v1
# Out:
# API base path: http://sysmlapiserver:9000
# Processing
# Posting Commit (29 elements)...
# c4ebce7e-6d6b-42ef-a63c-c54d9068bde9
# Saved to Project eVehicle_LogicalArchitecture_v1 Wed Jun 30 09:11:23 UTC 2021 (1a772c23-ce81-4f77-adfc-065befa63ecd)

# %% [markdown]
# **Viewing Projects**
#
# Once the model has been published, we can view our stored [project](http://localhost:9000/projects) in the API server.

# %% [markdown]
# ## show
#
# Which gives a textual outline of the Model.
#
# [Codebase](https://github.com/Systems-Modeling/SysML-v2-Pilot-Implementation/blob/master/org.omg.sysml.jupyter.kernel/src/main/java/org/omg/sysml/jupyter/kernel/magic/Show.java)

# %%
%show Objects
# Out:
# Package Objects (9812ae5c-5cbf-476b-b6ce-96d3071717b0)
#   [Membership Anything] Classifier Anything (1875fd5c-708e-490b-9125-94873c752931)
#   [Membership things] Feature things (f505323c-edb1-4c0d-839e-d899b1ac37c5)
#   [Import] Package Links (4f20e91f-afdc-4815-90ad-467ce84d23de)
#   [Membership Occurrence] Class Occurrence (9259ffef-2a54-47d8-8a21-d2efe137e52e)
#   [Membership Performance] Behavior Performance (512002f7-d0c8-4957-af22-0c3920a3d7f4)
#   [Membership performances] Step performances (58be8976-610d-4133-9648-f5413e10e1ef)
#   [Membership] Structure Object (36624b25-e374-41c3-8a4a-2c1e97bac4f3)
#     [Superclassing] Class Occurrence (9259ffef-2a54-47d8-8a21-d2efe137e52e)
#     [FeatureMembership] Feature self (ca612311-b2ec-4cad-93fb-bab7a050964d)
#       [FeatureTyping] Structure Object (36624b25-e374-41c3-8a4a-2c1e97bac4f3)
#       [Redefinition] Feature self (c65d7869-4356-4d0f-a88e-59fb9b4ea4f9)
#     [FeatureMembership] Step involvingPerformances (ffb7cea1-ca2a-4761-8cbc-e5330ecbe0cf)
#       [FeatureTyping] Behavior Performance (512002f7-d0c8-4957-af22-0c3920a3d7f4)
#       [Membership] MultiplicityRange (70a15e90-5bbd-4d5f-8b42-a0a1a98b803a)
#         [Subsetting (implicit)] Feature naturals (c6a14765-2cd9-4ff2-a9c9-90b69a1382fe)
#         [Membership] LiteralInteger (09093be8-32ad-4cbd-9a43-9003fde521f5)
