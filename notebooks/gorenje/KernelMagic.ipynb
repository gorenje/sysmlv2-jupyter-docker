# %% [markdown]
# # SysML v2 Kernel Magic Commands
#
# List of the kernel magic commands.
#
# Inspired by [MBSE4u.com](https://mbse4u.com/2020/12/21/sysml-v2-release-whats-inside/).
#
# ## list
#
# [Codebase](https://github.com/Systems-Modeling/SysML-v2-Pilot-Implementation/blob/master/org.omg.sysml.jupyter.kernel/src/main/java/org/omg/sysml/jupyter/kernel/magic/Listing.java)

# %%
%list
# Out:
# Package Actions (647aab39-9dc7-4f3b-8039-a988a5f1cc82)
# Package Allocations (4fa3a4e3-7dfe-45d5-a6a0-21a6211b3b0f)
# Package AnalysisCases (acc07a8a-63e5-402b-ae03-b8fc517d60a3)
# Package AnalysisTooling (46099dbb-b6f5-4de3-ac2d-01f3fdf1702b)
# Package Attributes (274e82e2-d408-4930-92c9-52f8540e2450)
# Package Base (c3f3bdb7-b792-49a8-a2f8-6c1beb8b3415)
# Package BaseFunctions (170347fb-f492-45bc-bc33-e7afb0cbabad)
# Package BasicGeometry (d43b0b12-9693-455f-b2f0-049203347d79)
# Package BooleanFunctions (914177e8-54bf-40c5-ab49-29f89e4443c5)
# Package Calculations (07a1bf87-dc86-45f1-a83e-b773a8e7442d)
# Package Cases (7dc0c1fc-2b4a-4125-bf1c-14544357791e)
# Package CollectionFunctions (04212505-f820-43dc-8926-b1227cb86d0b)
# Package Collections (3efa0df9-60b2-45af-abfb-2bf794b29b1e)
# Package ComplexFunctions (bec92448-159f-4a7f-a8d7-27ecca3080d1)
# Package Connections (0a8425ce-7cbb-462a-93ea-016fa48a20a7)
# Package Constraints (b633eeaa-838c-4bba-a2c4-aa15f6ec453a)
# Package ControlFunctions (5d9e00e9-9231-4424-8f18-261167255d18)
# Package ControlPerformances (48e5caa8-d618-40ea-97de-d889ec98eeac)
# Package DataFunctions (974cdfbe-109c-40ea-b10d-da9eba749d8a)
# Package IntegerFunctions (dd79ee18-6d1d-4090-914f-9bfed1abe78d)
# Package Interfaces (988b031a-d7aa-4097-a672-1046db54ae95)
# Package ISQ (b28ff702-4410-4c2b-b988-c71e414745f4)
# Package ISQAcoustics (2aff232a-6bc4-4ce6-8e68-8ae5da97af87)
# Package ISQAtomicNuclear (8432e8b1-dcde-4f23-89ba-fb7ad02bef74)
# Package ISQBase (8f9b9ac1-2aea-44f8-96c8-575be0d08666)
# Package ISQCharacteristicNumbers (8b70b46d-a39b-4426-a84f-0d28ccbb497b)
# Package ISQChemistryMolecular (51ec02a0-36d5-4330-a4fe-6d286b7a1586)
# Package ISQCondensedMatter (bfcfe7b0-3c55-4a8e-a536-a3a2790e0152)
# Package ISQElectromagnetism (4438210b-a5f3-4687-97c2-bc1ce246e71d)
# Package ISQInformation (8d693742-2e2d-4a55-a91d-8f339c643301)
# Package ISQLight (9a115999-b0df-4e5a-a9bb-32929602f744)
# Package ISQMechanics (37199f71-1314-45b7-b73e-273fb62b8295)
# Package ISQSpaceTime (657ad633-7ad3-4fe5-ade7-481f13606f8c)
# Package ISQThermodynamics (fa443e0e-3ec2-4133-9947-031d111a2a55)
# Package Items (02b95031-7fd7-40b9-b595-d91ece5419d0)
# Package KerML (88debb3f-e7af-48e1-9721-565b35293360)
# Package Links (70d4843c-d15a-4db3-89fe-d8968cde3ac7)
# Package NaturalFunctions (a594dc37-e8f4-4c45-8a1f-2b2d7a525b2f)
# Package NumericalFunctions (4bbfb12a-8641-4351-9913-adcf986ac1cc)
# Package Objects (cb965ea0-b18a-4bcf-ae08-96ac492cf1d0)
# Package Occurrences (26181790-cbb8-4e75-94d7-515b6246a22f)
# Package Parts (193b9e63-76a9-44da-9c63-f0fa1ae26ee6)
# Package Performances (aa69bfcb-107a-4e3c-93b3-8e5605ba1433)
# Package Ports (db7e3019-9a77-463a-befe-b404eaa248a3)
# Package Quantities (ff02e2f3-bf11-42da-a7dc-4ff9e7124751)
# Package QuantityCalculations (6a191824-2f2a-46eb-ac44-888cea6d23bc)
# Package RationalFunctions (dde3bef2-5a9a-4ebd-80e7-c11a0d42bf30)
# Package RealFunctions (4ecab457-befb-4526-b14c-0e54ae5d415b)
# Package Requirements (e10cda54-d129-46cd-9532-4206c17a1af7)
# Package ScalarFunctions (763b0049-270b-4425-a081-12b41772212f)
# Package ScalarValues (20d5801f-66ac-4621-b650-fa84f7fc906e)
# Package SequenceFunctions (ceb999ad-eb8b-4873-86cc-2ab54f0acdf9)
# Package SI (ef2abe38-8d65-4eff-8747-c4109fb3891a)
# Package SIPrefixes (ce3a804e-bc18-4f13-981b-92b4c97e1318)
# Package StatePerformances (a7b66419-8217-408a-a08a-5b2d40536258)
# Package States (5e39fd9b-5710-41bd-acd1-d794ed21d421)
# Package StateSpaceRepresentation (cb466f98-85d6-41c5-9f1d-78489a653354)
# Package StringFunctions (c4fdc1b6-f3d6-4ff7-bf94-9df4b5e6b728)
# Package SysML (4d2133e2-4ee4-46c3-8527-21874c83a78a)
# Package Time (c097c81b-34d8-49fb-a2c7-b0f2049fa632)
# Package TradeStudies (c61bfc82-210d-4cc4-924b-b0effe0115b5)
# Package Transfers (5b5bcd59-d54d-4f8b-bee1-452da6b102dc)
# Package TransitionPerformances (dbec3877-f6c2-46c4-93b0-3e041c952cd8)
# Package UnitsAndScales (c35a0cc7-7f58-47a4-9d33-ed273e8b8097)
# Package UnlimitedNaturalFunctions (2186b088-316a-4fd8-9c58-e1d580568f23)
# Package USCustomaryUnits (43c4d333-40e4-45ab-937e-9bcb733f1ca0)
# Package VerificationCases (a4c567b1-4cbd-4d29-8ce2-b602ef8afd83)
# Package Views (35a553c2-a6f8-4c62-9dde-c0e2fccc5aa1)

# %% [markdown]
# ### Limited querying is also possible.
#
# The query string works as an ["import"](https://github.com/Systems-Modeling/SysML-v2-Pilot-Implementation/blob/0be3bc228ad3cc56bfb9c340866c2ae59a6d2601/org.omg.sysml.interactive/src/org/omg/sysml/interactive/SysMLInteractive.java#L230) statement in Sysml. That is the following is to be intrepreted as `import Objects::*;` and then show all membership. The [specs](/files/doc/2-OMG_Systems_Modeling_Language_%28SysML%29.pdf) (page 108 of 413) provide an overview what can be passed to import. (If specs link doesn't work, [use this absolute link](https://github.com/Systems-Modeling/SysML-v2-Release/blob/master/doc/2-OMG_Systems_Modeling_Language_%28SysML%29.pdf))

# %%
%list "Objects::*"
# Out:
# AssociationStructure BinaryLinkObject (a256db5e-7f26-48ff-95fe-bcde853e43d2)
# Feature binaryLinkObjects (8875671c-1788-4536-902e-2b3b16628577)
# AssociationStructure LinkObject (0352a077-7d5c-4b70-b9af-02d5abb7ba7c)
# Feature linkObjects (4ecb98a0-9d77-4b76-804a-cc524b0341b3)
# Structure Object (2c411637-2fb6-4f25-ad2e-3460aa4246d8)
# Feature objects (2d83dd50-1cff-431d-b899-4fa0780e2c53)

# %%
%list "Objects::**"
# Out:
# Feature $collection (0cdd2441-5421-482f-ad51-43ad36eee91b)
# AssociationStructure BinaryLinkObject (a256db5e-7f26-48ff-95fe-bcde853e43d2)
# Feature binaryLinkObjects (8875671c-1788-4536-902e-2b3b16628577)
# Step enactedPerformances (26490f01-f631-413a-b10d-abd0c45c2609)
# Feature incomingTransfers (25d02abd-0bbc-4cea-ac7c-0502d15e5cb5)
# Feature incomingTransfersToSelf (1a0007b2-a387-44f0-8323-c412d7ad96f3)
# BindingConnector instant (bb61c6b8-5d23-45c1-bc34-022fd557c241)
# Feature involvedObjects (7aa3aa8b-731a-4794-bc79-ffd6a1872c97)
# Step involvingPerformances (660041cd-0401-4801-afe8-7d9d02988aaf)
# Feature isInstant (ea87a8f8-23b8-4935-a6dd-138d26a119df)
# Feature isMove (fe7ed4c5-bf6f-4f56-99ca-ee6701115a41)
# Feature isPush (1368d80b-a21d-48e0-882c-7824f1962cda)
# Feature item (726e348b-5531-494b-b6fe-d3156afbcd5a)
# AssociationStructure LinkObject (0352a077-7d5c-4b70-b9af-02d5abb7ba7c)
# Feature linkObjects (4ecb98a0-9d77-4b76-804a-cc524b0341b3)
# Feature longerOccurrence (439451d6-504e-433b-8dc9-accc966ad807)
# Feature middleShots (3a57f1a1-6ada-4230-b989-9d9ed3755907)
# Connector moving (249fbbd2-a8dd-425c-b769-0fbcd95c0f8f)
# Structure Object (2c411637-2fb6-4f25-ad2e-3460aa4246d8)
# Feature objects (2d83dd50-1cff-431d-b899-4fa0780e2c53)
# Package Objects (cb965ea0-b18a-4bcf-ae08-96ac492cf1d0)
# Feature outgoingTransfers (27bdf484-3aae-48e4-890e-8272aabe957d)
# Feature outgoingTransfersFromSelf (f4623cc9-1a6d-407a-acaf-999a572820ed)
# Feature participant (0fc8926d-d203-4e94-b1e7-a6debdb3a5aa)
# Feature performers (b368674e-c2c4-4102-b1fa-4e9f34c56f9b)
# Feature portionOf (01a96163-4be8-4979-8d6d-d6cc381903c8)
# Feature portionOfLife (35964ba7-783e-4749-97a1-5777bee6a4c5)
# Feature portions (d80e170b-d0d5-491f-bf15-c75f1a28fff0)
# Feature predecessors (f8ee04cf-b149-4ba3-8626-0ff5ee02a25e)
# Connector pushing (aa19d68a-d4f5-41fc-84e3-f0bc48e4acbc)
# Feature s (a7ee26dc-8ee2-4ffb-abea-fada05563e6d)
# Feature shorterOccurrence (9dc32e12-5b13-4eb6-a10b-30bc34ac8ec2)
# Feature snapshotOf (18ae1099-070b-4405-abfb-a5b2d87d5c43)
# Feature snapshots (3d0b840e-e730-41d7-8b33-72bf667233df)
# Feature sourceOutput (664d33c0-9aa0-49fe-92d7-e6498bcef25f)
# AssociationStructure SourceOutputLink (dfa72efe-b12c-402b-afb6-2ca4053f7b7e)
# Connector sourceOutputLink (01f44317-d433-4f2e-837e-8956d5bfb3e2)
# Expression subBooleanEvaluations (0c51f8b0-a94d-4d24-b22b-2684c4a6d9f7)
# Expression subevaluations (80422adf-eb7e-492c-a97f-f6ca38e9ef19)
# Step subflows (5c4da4a0-f16c-477c-9579-af9811d35862)
# Feature suboccurrences (cb3543b2-a86a-4e30-833a-f11703b81e0c)
# Step subperformances (91c2c252-8117-477b-9ebf-0078c7c1955e)
# Step subtransfers (5fab15ee-24e2-450a-8534-fdc596608ee5)
# Feature successors (359d8750-3347-447a-8943-127b730996f4)
# Feature targetInput (825bb9ba-9613-45c4-a754-e7cf40734e72)
# AssociationStructure TargetInputLink (be96c220-8b43-4267-b36f-d904672bf47f)
# Connector targetInputLink (afac7d3a-6abb-46e7-b5d8-93ea584d55c2)
# Feature timeSliceOf (df942f24-2f5e-4dd0-a637-d84db60f735c)
# Feature timeSlices (77c2d5e0-fb27-41ca-a343-34f4300818e3)

# %% [markdown]
# It is also possible to have a filter condition %list namespace::**[filterCondition]

# %% [markdown]
# ## viz
#
# Graphviz'ify elements from the model.
#
# [Codebase](https://github.com/Systems-Modeling/SysML-v2-Pilot-Implementation/blob/master/org.omg.sysml.jupyter.kernel/src/main/java/org/omg/sysml/jupyter/kernel/magic/Viz.java) and [Kernel Code](https://github.com/Systems-Modeling/SysML-v2-Pilot-Implementation/blob/0be3bc228ad3cc56bfb9c340866c2ae59a6d2601/org.omg.sysml.interactive/src/org/omg/sysml/interactive/SysMLInteractive.java#L283-L316)
#
# Viz supports '-h' option for displaying some help:

# %%
%viz -h
# Out:
# Usage: %viz [--view=<VIEW>] [--style=<STYLE>...] <NAME> [<NAME>...]
#
# Visualize model elements of <NAME>(s). <NAME>s must be fully qualified.
#
# <VIEW> is case insensitive and possible candidates are:
#    DEFAULT		Automatically choose an appropriate view from the given model element names
#    TREE			Show a tree-structural view, like a Block Definition Diagram (BDD)
#    INTERCONNECTION	Show an interconnection view, like an Internal Block Diagram (IBD)
#    STATE		Show state machines
#    ACTION		Show actions like an activity diagram
#    MIXED		Show multiple views
#
# <STYLE> is also case insensitive. Multiple --style options are allowed.  The possible style names are:
#    DEFAULT		Standard B&W format
#    STDCOLOR		Standard format with colors
#    PLANTUML		PlantUML format
#    PUMLCODE		Show PlantUML code mainly for debugging
#    TB			Top-to-Bottom orientation
#    LR			Left-to-Right orientation
#    POLYLINE		Polyline style
#    ORTHOLINE		Orthogonal line style
#    COMPTREE		Show tree structures in compartments

# %% [markdown]
# Generating a graph:

# %%
%viz "VerificationCases"

# %%
%viz "Objects" --style="PLANTUML"

# %% [markdown]
# ### Arguments to %viz
#
# - style : COMPTREE, POLYLINE, LR, STDCOLOR, PLANTUML, DEFAULT, TB, ORTHOLINE
# - view : Default Tree State Interconnection Action Sequence MIXED

# %%
%viz "Objects" --view=State --style="PLANTUML"

# %% [markdown]
# ### %viz Hidden Option
#
# There is also a hidden style option: `PUMLCODE` to get the original plant UML code of the diagram.

# %%
%viz --style=PUMLCODE Views
# Out:
# @startuml
# skinparam monochrome true
# skinparam classbackgroundcolor white
# skinparam shadowing false
# skinparam wrapWidth 300
# hide circle
#
# note as E1
# [[psysml:52ce3cff-d917-410d-96d5-437c08b97785 @]]Ports that are on this Part.
#
# end note
# rec usage "exhibitedStates" as E3 [[psysml:65e2e71d-5ff1-4c6e-9203-4cb799602c93 ]] {
# }
#
# note as E2
# [[psysml:75967b97-3fb4-4248-b8e0-8dc1af754fef @]]Actions that are performed by this Part.
#
# end note
# note as E4
# [[psysml:9e10792c-ca48-41e9-8249-e9d0683fdfd1 @]]States that are exhibited by this Part.
#
# end note
# E4 .. E3 [[psysml:9e10792c-ca48-41e9-8249-e9d0683fdfd1 ]]
# note as E5
# [[psysml:c261f01e-fbdc-4308-95bc-1ae6b65c6075 @]]The entity that is being checked for satisfaction of the required constraints.
#
# end note
# note as E6
# [[psysml:4226c731-9b7e-472c-82e7-69d8459906ce @]]Note: assumptions and constraints are redefined here solely to simplify the
# resolution of their qualified names as library elements.
#
# end note
# note as E7
# [[psysml:37616a41-6e40-40ea-99f0-c6511dd40bb5 @]]Nested requirements, which are also required constraints.
#
# end note
# note as E8
# [[psysml:326436f6-30f5-4340-87be-1d257f2523f4 @]]The checks of any concerns being addressed (as required constraints).
#
# end note
# note as E9
# [[psysml:86811e46-c8e8-4124-9e07-9f1ac2332f61 @]]Other Views that are used in the rendering of this View.
#
# end note
# note as E10
# [[psysml:21acfbdf-e845-4a3f-9703-1c297119e14f @]]The rendering of this View.
#
# end note
# note as E11
# [[psysml:5680a62c-6bc8-44ce-be06-f4caf3c19a3e @]]Checks that the View satisfies all required ViewpointsUsages.
#
# end note
# note as E12
# [[psysml:d3851deb-a9a7-44f5-b1d1-53cb8ff299c7 @]]The required ViewpointChecks.
# end note
# note as E13
# [[psysml:a14e9672-4237-4d93-aa31-ab087181f5ad @]]An assertion that all viewpointSatisfactions are true.
#
# end note
# note as E14
# [[psysml:88bdaafc-0070-455f-88e9-cc15676c1d98 @]]ViewpointCheck is a RequirementCheck for checking if a View meets the concerns of viewpoint stakeholders.
# It is the base type of all ViewpointDefinitions.
#
# end note
# note as E15
# [[psysml:1ca6c4db-e7d0-4e0f-80ad-3e9f5326252e @]]Other Renderings used to carry out this Rendering.
#
# end note
# note as E16
# [[psysml:e5679bac-39c1-4255-b62e-163f6ae0e793 @]]Rendering is the base type of all RenderingDefinitions.
#
# end note
# note as E17
# [[psysml:bc2cc980-93cc-4c21-b356-5960785c4bd2 @]]A TextualRendering is a Rendering of a View into a textual format.
#
# end note
# note as E18
# [[psysml:a5baa2c1-eb8b-4273-90d8-31797133b09a @]]A GraphicalRendering is a Rendering of a View into a Graphical format.
#
# end note
# note as E19
# [[psysml:f46647c6-4a7e-4dc4-ae7f-78fcc98f66f5 @]]A TabularRendering is a Rendering of a View into a tabular format.
#
# end note
# note as E20
# [[psysml:7ac26d41-29d0-44b0-82b3-b8dc52bdfc91 @]]views is the base feature of all ViewUsages.
#
# end note
# note as E21
# [[psysml:3a2d0d4c-499b-44bb-94cd-fa0b41278b62 @]]viewpointChecks is the base feature of all ViewpointUsages.
#
# end note
# note as E22
# [[psysml:cbc3c4b1-cb49-43b2-bfab-2202d8e6f0ed @]]renderings is the base feature of all RenderingUsages.
#
# end note
# note as E23
# [[psysml:97dcedf9-f25d-4f26-b6ab-81cf66309722 @]]asTextualNotation renders a View into textual notation as defined in the
# KerML and SysML specifications.
#
# end note
# note as E24
# [[psysml:81c5ae96-ec2b-4dc9-a34c-f41111a2fddf @]]asTreeDiagram renders a View as a tree diagram, using the
# graphical notation defined in the SysML specification.
#
# end note
# note as E25
# [[psysml:cc2f5585-af68-4bee-a781-2e8ef8dacc6a @]]asInterconnectionDiagram renders a View as an interconnection
# diagram, using the graphical notation defined in the SysML specification.
#
# end note
# note as E26
# [[psysml:bfa83d38-a8c5-4042-b711-b2ad671f8fbb @]]The Views to be rendered in the column cells, in order, of each rows of the table.
#
# end note
# note as E27
# [[psysml:c13542a9-6a2c-4dce-aad9-26d6568c7c1b @]]asElementTable  renders a View as a table, with one row for each exposed
# Element and columns rendered by applying the columnViews in order to the
# Element in each row.
#
# end note
# @enduml

# %% [markdown]
# ## publish
#
# Push models to publish the model to a SysML v2 repository server.
#
# [Codebase](https://github.com/Systems-Modeling/SysML-v2-Pilot-Implementation/blob/master/org.omg.sysml.jupyter.kernel/src/main/java/org/omg/sysml/jupyter/kernel/magic/Publish.java)

# %%
%publish "Views"
# Out:
# ERROR:'Views' is a library element

# %% [markdown]
# So library elements can't be published, so we'll create a package and publish that.
#
# Package take from [MBSE4U Notebook](https://nbviewer.jupyter.org/github/MBSE4U/SysMLv2JupyterBook/blob/master/SysMLv2JupyterBook.ipynb).

# %%
package eVehicle_LogicalArchitecture_v1 {
    part eVehicle {    
        part body;
        part battery;
        part engine;
        part frontAxis;
        part rearAxis;
        part frontWheel[2];
        part rearWheel[2];
    }
}
# Out:
# Package eVehicle_LogicalArchitecture_v1 (64473da9-7502-427f-84d9-e23ab43311b9)

# %%
%publish eVehicle_LogicalArchitecture_v1
# Out:
# API base path: http://sysmlapiserver:9000
# Processing
# Posting Commit (29 elements)...
# ea5c1382-460e-42fc-abc5-8c8d005bf215
# Saved to Project eVehicle_LogicalArchitecture_v1 Thu May 27 06:04:14 UTC 2021 (54267652-95bb-4490-a7af-510625c75b9c)

# %% [markdown]
# **Viewing Projects**
#
# Once the model has been published, we can view our stored [project](http://localhost:9000/projects) in the API server.

# %% [markdown]
# ## show
#
# Which gives a textual outline of the Model.
#
# [Codebase](https://github.com/Systems-Modeling/SysML-v2-Pilot-Implementation/blob/master/org.omg.sysml.jupyter.kernel/src/main/java/org/omg/sysml/jupyter/kernel/magic/Show.java)

# %%
%show Objects
# Out:
# Package Objects (cb965ea0-b18a-4bcf-ae08-96ac492cf1d0)
#   [Membership Anything] Classifier Anything (b074163d-cc6b-4f19-a16e-5c6136ba2a1a)
#   [Membership things] Feature things (4b3817ff-0396-44e5-a646-d62b2bbccdbe)
#   [Import] Package Links (70d4843c-d15a-4db3-89fe-d8968cde3ac7)
#   [Membership Occurrence] Class Occurrence (5d57aff7-804e-4078-84d3-7456b36f28b1)
#   [Membership Performance] Behavior Performance (5f84b37f-e70c-4b0e-939d-793735b594f5)
#   [Membership performances] Step performances (9c101673-453e-427d-801f-b3f93dc687c0)
#   [Membership] Structure Object (2c411637-2fb6-4f25-ad2e-3460aa4246d8)
#     [Superclassing] Class Occurrence (5d57aff7-804e-4078-84d3-7456b36f28b1)
#     [FeatureMembership] Feature self (d4952a21-97d4-427b-a4c6-026839e71218)
#       [FeatureTyping] Structure Object (2c411637-2fb6-4f25-ad2e-3460aa4246d8)
#       [Redefinition] Feature self (2e5a07e7-5783-4519-9c32-39696f1f0f46)
#     [FeatureMembership] Step involvingPerformances (660041cd-0401-4801-afe8-7d9d02988aaf)
#       [FeatureTyping] Behavior Performance (5f84b37f-e70c-4b0e-939d-793735b594f5)
#       [Membership] MultiplicityRange (dbebf565-14ac-4540-a744-143fd7008c04)
#         [Subsetting (implicit)] Feature naturals (7a5d37eb-7fea-445e-a7ac-c630a8bd8e53)
#         [Membership] LiteralInteger (abd3ce74-9c28-4a8d-ae7e-444ae3e16361)
#           [ReturnParameterMembership] Feature $result (6ffe44dd-fa01-4434-b9e9-c8194ee94673)
#         [Membership] LiteralUnbounded (a02f3417-7e76-4309-a72a-234292afc823)
#           [ReturnParameterMembership] Feature $result (03ec8391-bf08-4277-bec0-51112f70a224)
#       [Subsetting] Step performances (9c101673-453e-427d-801f-b3f93dc687c0)
#     [FeatureMembership] Step enactedPerformances (26490f01-f631-413a-b10d-abd0c45c2609)
#       [FeatureTyping] Behavior Performance (5f84b37f-e70c-4b0e-939d-793735b594f5)
#       [Membership] MultiplicityRange (bcc71b94-c479-442b-b716-39147dae9ff7)
#         [Subsetting (implicit)] Feature naturals (7a5d37eb-7fea-445e-a7ac-c630a8bd8e53)
#         [Membership] LiteralInteger (0a6325a7-d61d-4c7d-82d8-1cac2cca7948)
#           [ReturnParameterMembership] Feature $result (c51d4135-9cac-41c8-9208-671649288646)
#         [Membership] LiteralUnbounded (e5a68097-9d41-4e47-88db-73725a50d4f0)
#           [ReturnParameterMembership] Feature $result (05bcc472-28d2-465a-a9c0-121485532649)
#       [Subsetting] Step involvingPerformances (660041cd-0401-4801-afe8-7d9d02988aaf)
#       [Subsetting] Feature suboccurrences (cb3543b2-a86a-4e30-833a-f11703b81e0c)
#   [Membership] AssociationStructure LinkObject (0352a077-7d5c-4b70-b9af-02d5abb7ba7c)
#     [Superclassing] Association Link (12c8d1fe-e4e9-47c5-b566-ed0063972906)
#     [Superclassing] Structure Object (2c411637-2fb6-4f25-ad2e-3460aa4246d8)
#   [Membership] AssociationStructure BinaryLinkObject (a256db5e-7f26-48ff-95fe-bcde853e43d2)
#     [Superclassing] Association BinaryLink (03a498a5-3c33-4d98-9056-c90c377c9a07)
#     [Superclassing] AssociationStructure LinkObject (0352a077-7d5c-4b70-b9af-02d5abb7ba7c)
#     [EndFeatureMembership] Feature source (bf517b84-3aee-417a-8085-077fa3c09c2e)
#       [Redefinition (implicit)] Feature source (a757cfaa-b3c7-48a6-8953-1eaf2569b28b)
#       [FeatureTyping] Classifier Anything (b074163d-cc6b-4f19-a16e-5c6136ba2a1a)
#       [Membership] MultiplicityRange (88050c8a-6c6c-4f91-a07e-9b5ef50fbfe8)
#         [Subsetting (implicit)] Feature naturals (7a5d37eb-7fea-445e-a7ac-c630a8bd8e53)
#         [Membership] LiteralInteger (56df1c74-9143-466d-b35a-aa2eea5b9929)
#           [ReturnParameterMembership] Feature $result (9fa85b60-8d9d-4783-8f89-c1cacd300453)
#         [Membership] LiteralUnbounded (dca92e24-5bcc-4434-b08f-e0ff6b9b52eb)
#           [ReturnParameterMembership] Feature $result (01811381-2f64-485b-b39a-8e91c814565c)
#       [Subsetting] Feature source (a757cfaa-b3c7-48a6-8953-1eaf2569b28b)
#     [EndFeatureMembership] Feature target (a4bb8360-acc3-4e8b-a216-9537c8e2c782)
#       [Redefinition (implicit)] Feature target (2cbb64df-3bf4-4279-bd68-892c0fcfacd1)
#       [FeatureTyping] Classifier Anything (b074163d-cc6b-4f19-a16e-5c6136ba2a1a)
#       [Membership] MultiplicityRange (3b73d67c-a135-4d33-b2a5-10d055f490a7)
#         [Subsetting (implicit)] Feature naturals (7a5d37eb-7fea-445e-a7ac-c630a8bd8e53)
#         [Membership] LiteralInteger (53bc3091-01a2-47ef-9cb0-9abd322f8b12)
#           [ReturnParameterMembership] Feature $result (022c56d2-fa22-47d8-9c0d-073beda564a4)
#         [Membership] LiteralUnbounded (381e99ee-85a7-4fc9-8e74-6d0306d12787)
#           [ReturnParameterMembership] Feature $result (6d830ab3-7a18-4ddd-961c-47cf59bbea03)
#       [Subsetting] Feature target (2cbb64df-3bf4-4279-bd68-892c0fcfacd1)
#   [Membership] Feature objects (2d83dd50-1cff-431d-b899-4fa0780e2c53)
#     [FeatureTyping] Structure Object (2c411637-2fb6-4f25-ad2e-3460aa4246d8)
#     [Membership] MultiplicityRange (7dee13f1-ab38-4272-9400-e037696de24f)
#       [Subsetting (implicit)] Feature naturals (7a5d37eb-7fea-445e-a7ac-c630a8bd8e53)
#       [Membership] LiteralInteger (7e704146-76a0-45f0-a588-8a7746df6d90)
#         [ReturnParameterMembership] Feature $result (677cf084-07e1-4aa5-918e-b6a3041727cd)
#       [Membership] LiteralUnbounded (301588aa-3b6d-4b1f-97de-c5fd5dc01306)
#         [ReturnParameterMembership] Feature $result (ab7d6445-77e3-4def-9a38-36e21145a109)
#     [Subsetting] Feature things (4b3817ff-0396-44e5-a646-d62b2bbccdbe)
#   [Membership] Feature linkObjects (4ecb98a0-9d77-4b76-804a-cc524b0341b3)
#     [FeatureTyping] AssociationStructure LinkObject (0352a077-7d5c-4b70-b9af-02d5abb7ba7c)
#     [Membership] MultiplicityRange (ebb7c974-9d51-47cf-a112-792417bdfc25)
#       [Subsetting (implicit)] Feature naturals (7a5d37eb-7fea-445e-a7ac-c630a8bd8e53)
#       [Membership] LiteralInteger (4bf0a8af-b47b-4871-bd80-ab097e46d87b)
#         [ReturnParameterMembership] Feature $result (ee938013-ff75-44f6-ac0b-bf3407f6f976)
#       [Membership] LiteralUnbounded (47b566a8-897e-4c8a-a0c0-c70c4dd7355b)
#         [ReturnParameterMembership] Feature $result (776a4f41-162d-4476-8f4e-5460ea4ee8d0)
#     [Subsetting] Feature links (e5fbab55-1637-4ad1-90a3-3ca5bdbff248)
#     [Subsetting] Feature objects (2d83dd50-1cff-431d-b899-4fa0780e2c53)
#   [Membership] Feature binaryLinkObjects (8875671c-1788-4536-902e-2b3b16628577)
#     [FeatureTyping] AssociationStructure BinaryLinkObject (a256db5e-7f26-48ff-95fe-bcde853e43d2)
#     [Membership] MultiplicityRange (96ccb912-0cb9-4c1c-affe-160ff43aef61)
#       [Subsetting (implicit)] Feature naturals (7a5d37eb-7fea-445e-a7ac-c630a8bd8e53)
#       [Membership] LiteralInteger (410bec58-425f-4ff9-8405-1cc52964c690)
#         [ReturnParameterMembership] Feature $result (d52a8174-b107-46d0-9c22-d71b585e16c7)
#       [Membership] LiteralUnbounded (d998ca09-f72a-41c3-b800-f3693fd7799b)
#         [ReturnParameterMembership] Feature $result (2cee9653-a233-481d-869c-9ea7b2ddb758)
#     [Subsetting] Feature binaryLinks (6e77605a-1455-445c-b983-dca73d3eeaa7)
#     [Subsetting] Feature linkObjects (4ecb98a0-9d77-4b76-804a-cc524b0341b3)
