# %% [markdown]
# # SysML v2 Test Suite
#
# This can notebook can be cleared using menu `Edit --> Clear All Outputs` and then all cells can be
# run using menu `Run --> Run All Cells`.
#
# **WARNING**: This file is generated, all modifications here will be ignored.

# %% [markdown]
# ## File: ../../sysml/src/examples/Simple Tests/AssignmentTest.sysml

# %%
package AssignmentTest {
	
	part def Counter {
		attribute count : ScalarValues::Integer := 0;
		
		action incr {
			assign count := count + 1;
		}
		
		action decr {
			assign count := count - 1;
		}
	}
	
	attribute def Incr;
	attribute def Decr;
	
	state def Counting {
		part counter : Counter;
		entry assign counter.count := 0;
		
		then state wait;
		accept Incr
			then increment;
		accept Decr
			then decrement;
		
		state increment {
			do assign counter.count := counter.count + 1;
		}
		then wait;
		
		state decrement {
			do assign counter.count := counter.count - 1;
		}
		then wait;
	}
	
	calc def Increment { 
		in c : Counter;
		return : Counter;
		
		perform c.incr;
		c
	}
	
	action a {
		state counting : Counting;
		assign counting.counter.count := counting.counter.count + 1;
		assign counting.counter.count := Increment(counting.counter).count;
	}
}
# Out:
# Package AssignmentTest (09299527-6744-4121-b47e-0755c4ad0275)

# %%
%viz --style="COMPTREE" --view="Default" "AssignmentTest"

# %%
%viz --style="COMPTREE" --view="Tree" "AssignmentTest"

# %%
%viz --style="COMPTREE" --view="State" "AssignmentTest"

# %%
%viz --style="COMPTREE" --view="Interconnection" "AssignmentTest"

# %%
%viz --style="COMPTREE" --view="Action" "AssignmentTest"

# %%
%viz --style="COMPTREE" --view="Sequence" "AssignmentTest"

# %%
%viz --style="COMPTREE" --view="MIXED" "AssignmentTest"

# %%
%viz --style="POLYLINE" --view="Default" "AssignmentTest"

# %%
%viz --style="POLYLINE" --view="Tree" "AssignmentTest"

# %%
%viz --style="POLYLINE" --view="State" "AssignmentTest"

# %%
%viz --style="POLYLINE" --view="Interconnection" "AssignmentTest"

# %%
%viz --style="POLYLINE" --view="Action" "AssignmentTest"

# %%
%viz --style="POLYLINE" --view="Sequence" "AssignmentTest"

# %%
%viz --style="POLYLINE" --view="MIXED" "AssignmentTest"

# %%
%viz --style="LR" --view="Default" "AssignmentTest"

# %%
%viz --style="LR" --view="Tree" "AssignmentTest"

# %%
%viz --style="LR" --view="State" "AssignmentTest"

# %%
%viz --style="LR" --view="Interconnection" "AssignmentTest"

# %%
%viz --style="LR" --view="Action" "AssignmentTest"

# %%
%viz --style="LR" --view="Sequence" "AssignmentTest"

# %%
%viz --style="LR" --view="MIXED" "AssignmentTest"

# %%
%viz --style="STDCOLOR" --view="Default" "AssignmentTest"

# %%
%viz --style="STDCOLOR" --view="Tree" "AssignmentTest"

# %%
%viz --style="STDCOLOR" --view="State" "AssignmentTest"

# %%
%viz --style="STDCOLOR" --view="Interconnection" "AssignmentTest"

# %%
%viz --style="STDCOLOR" --view="Action" "AssignmentTest"

# %%
%viz --style="STDCOLOR" --view="Sequence" "AssignmentTest"

# %%
%viz --style="STDCOLOR" --view="MIXED" "AssignmentTest"

# %%
%viz --style="PLANTUML" --view="Default" "AssignmentTest"

# %%
%viz --style="PLANTUML" --view="Tree" "AssignmentTest"

# %%
%viz --style="PLANTUML" --view="State" "AssignmentTest"

# %%
%viz --style="PLANTUML" --view="Interconnection" "AssignmentTest"

# %%
%viz --style="PLANTUML" --view="Action" "AssignmentTest"

# %%
%viz --style="PLANTUML" --view="Sequence" "AssignmentTest"

# %%
%viz --style="PLANTUML" --view="MIXED" "AssignmentTest"

# %%
%viz --style="DEFAULT" --view="Default" "AssignmentTest"

# %%
%viz --style="DEFAULT" --view="Tree" "AssignmentTest"

# %%
%viz --style="DEFAULT" --view="State" "AssignmentTest"

# %%
%viz --style="DEFAULT" --view="Interconnection" "AssignmentTest"

# %%
%viz --style="DEFAULT" --view="Action" "AssignmentTest"

# %%
%viz --style="DEFAULT" --view="Sequence" "AssignmentTest"

# %%
%viz --style="DEFAULT" --view="MIXED" "AssignmentTest"

# %%
%viz --style="TB" --view="Default" "AssignmentTest"

# %%
%viz --style="TB" --view="Tree" "AssignmentTest"

# %%
%viz --style="TB" --view="State" "AssignmentTest"

# %%
%viz --style="TB" --view="Interconnection" "AssignmentTest"

# %%
%viz --style="TB" --view="Action" "AssignmentTest"

# %%
%viz --style="TB" --view="Sequence" "AssignmentTest"

# %%
%viz --style="TB" --view="MIXED" "AssignmentTest"

# %%
%viz --style="ORTHOLINE" --view="Default" "AssignmentTest"

# %%
%viz --style="ORTHOLINE" --view="Tree" "AssignmentTest"

# %%
%viz --style="ORTHOLINE" --view="State" "AssignmentTest"

# %%
%viz --style="ORTHOLINE" --view="Interconnection" "AssignmentTest"

# %%
%viz --style="ORTHOLINE" --view="Action" "AssignmentTest"

# %%
%viz --style="ORTHOLINE" --view="Sequence" "AssignmentTest"

# %%
%viz --style="ORTHOLINE" --view="MIXED" "AssignmentTest"
