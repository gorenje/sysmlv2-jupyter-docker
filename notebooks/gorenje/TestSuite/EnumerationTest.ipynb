# %% [markdown]
# # SysML v2 Test Suite
#
# This can notebook can be cleared using menu `Edit --> Clear All Outputs` and then all cells can be
# run using menu `Run --> Run All Cells`.
#
# **WARNING**: This file is generated, all modifications here will be ignored.

# %% [markdown]
# ## File: ../../sysml/src/examples/Simple Tests/EnumerationTest.sysml

# %%
package EnumerationTest {
	
	attribute def Color {
		attribute val : ScalarValues::Natural;
	}
	
	/**
	 * An EnumerationDefinition can contain only EnumerationUsages. However,
	 * it can specialize an AttributeDefinition in order to inherit
	 * common features for its enumeration values.
	 */
	enum def ColorKind :> Color {
		enum red {
			:>> val = 0;
		}
		enum blue {
			:>> val = 1;
		}
		enum green {
			:>> val = 2;
		}
	}
	
	enum color : ColorKind;
	attribute color1 : ColorKind = ColorKind::blue;
	
	/** 
	 * Note that "blue" can be used without qualification here because,
	 * currently, names in the expression on the right-hand side are
	 * resolved in the scope of the feature being declared, which inherits
	 * the members of its type.
	 */
	attribute color2 : ColorKind = blue;
	
	/**
	 * The "enum" keyword is optional for EnumerationUsages used to define the
	 * enumerated values of an EnumerationDefinition.
	 */
	enum def E1 { a; b; c; }
	
	enum def E2;
	
	/**
	 * An EnumerationDefinition can also be used to restrict a supertype to
	 * specific values.
	 */
	attribute def Size :> ScalarValues::Real;		
	enum def SizeChoice :> Size {
		= 60.0;
		= 70.0;
		= 80.0;
	}	
	enum size: SizeChoice = 60.0;
	
}
# Out:
# Package EnumerationTest (74b6daf4-5aa3-45b2-8fa7-819ea7d11964)

# %%
%viz --style="COMPTREE" --view="Default" "EnumerationTest"

# %%
%viz --style="COMPTREE" --view="Tree" "EnumerationTest"

# %%
%viz --style="COMPTREE" --view="State" "EnumerationTest"

# %%
%viz --style="COMPTREE" --view="Interconnection" "EnumerationTest"

# %%
%viz --style="COMPTREE" --view="Action" "EnumerationTest"

# %%
%viz --style="COMPTREE" --view="Sequence" "EnumerationTest"

# %%
%viz --style="COMPTREE" --view="MIXED" "EnumerationTest"

# %%
%viz --style="POLYLINE" --view="Default" "EnumerationTest"

# %%
%viz --style="POLYLINE" --view="Tree" "EnumerationTest"

# %%
%viz --style="POLYLINE" --view="State" "EnumerationTest"

# %%
%viz --style="POLYLINE" --view="Interconnection" "EnumerationTest"

# %%
%viz --style="POLYLINE" --view="Action" "EnumerationTest"

# %%
%viz --style="POLYLINE" --view="Sequence" "EnumerationTest"

# %%
%viz --style="POLYLINE" --view="MIXED" "EnumerationTest"

# %%
%viz --style="LR" --view="Default" "EnumerationTest"

# %%
%viz --style="LR" --view="Tree" "EnumerationTest"

# %%
%viz --style="LR" --view="State" "EnumerationTest"

# %%
%viz --style="LR" --view="Interconnection" "EnumerationTest"

# %%
%viz --style="LR" --view="Action" "EnumerationTest"

# %%
%viz --style="LR" --view="Sequence" "EnumerationTest"

# %%
%viz --style="LR" --view="MIXED" "EnumerationTest"

# %%
%viz --style="STDCOLOR" --view="Default" "EnumerationTest"

# %%
%viz --style="STDCOLOR" --view="Tree" "EnumerationTest"

# %%
%viz --style="STDCOLOR" --view="State" "EnumerationTest"

# %%
%viz --style="STDCOLOR" --view="Interconnection" "EnumerationTest"

# %%
%viz --style="STDCOLOR" --view="Action" "EnumerationTest"

# %%
%viz --style="STDCOLOR" --view="Sequence" "EnumerationTest"

# %%
%viz --style="STDCOLOR" --view="MIXED" "EnumerationTest"

# %%
%viz --style="PLANTUML" --view="Default" "EnumerationTest"

# %%
%viz --style="PLANTUML" --view="Tree" "EnumerationTest"

# %%
%viz --style="PLANTUML" --view="State" "EnumerationTest"

# %%
%viz --style="PLANTUML" --view="Interconnection" "EnumerationTest"

# %%
%viz --style="PLANTUML" --view="Action" "EnumerationTest"

# %%
%viz --style="PLANTUML" --view="Sequence" "EnumerationTest"

# %%
%viz --style="PLANTUML" --view="MIXED" "EnumerationTest"

# %%
%viz --style="DEFAULT" --view="Default" "EnumerationTest"

# %%
%viz --style="DEFAULT" --view="Tree" "EnumerationTest"

# %%
%viz --style="DEFAULT" --view="State" "EnumerationTest"

# %%
%viz --style="DEFAULT" --view="Interconnection" "EnumerationTest"

# %%
%viz --style="DEFAULT" --view="Action" "EnumerationTest"

# %%
%viz --style="DEFAULT" --view="Sequence" "EnumerationTest"

# %%
%viz --style="DEFAULT" --view="MIXED" "EnumerationTest"

# %%
%viz --style="TB" --view="Default" "EnumerationTest"

# %%
%viz --style="TB" --view="Tree" "EnumerationTest"

# %%
%viz --style="TB" --view="State" "EnumerationTest"

# %%
%viz --style="TB" --view="Interconnection" "EnumerationTest"

# %%
%viz --style="TB" --view="Action" "EnumerationTest"

# %%
%viz --style="TB" --view="Sequence" "EnumerationTest"

# %%
%viz --style="TB" --view="MIXED" "EnumerationTest"

# %%
%viz --style="ORTHOLINE" --view="Default" "EnumerationTest"

# %%
%viz --style="ORTHOLINE" --view="Tree" "EnumerationTest"

# %%
%viz --style="ORTHOLINE" --view="State" "EnumerationTest"

# %%
%viz --style="ORTHOLINE" --view="Interconnection" "EnumerationTest"

# %%
%viz --style="ORTHOLINE" --view="Action" "EnumerationTest"

# %%
%viz --style="ORTHOLINE" --view="Sequence" "EnumerationTest"

# %%
%viz --style="ORTHOLINE" --view="MIXED" "EnumerationTest"
