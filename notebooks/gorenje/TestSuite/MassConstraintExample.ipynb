# %% [markdown]
# # SysML v2 Test Suite
#
# This can notebook can be cleared using menu `Edit --> Clear All Outputs` and then all cells can be
# run using menu `Run --> Run All Cells`.
#
# **WARNING**: This file is generated, all modifications here will be ignored.

# %% [markdown]
# ## File: ../../sysml/src/examples/Mass Roll-up Example/MassConstraintExample.sysml

# %%
package MassConstraintExample {
	import ISQ::*;
	import SI::*;
	import ScalarFunctions::*;
	
	part def Engine {
		attribute m :> mass;
	}
	
	part def Transmission {
		attribute m :> mass;
	}
	
	part def Vehicle1 {
		attribute m : MassValue = eng::m + trans::m;
		
		part eng : Engine {
			attribute :>> m : MassValue;
		}
		
		part trans : Transmission {
			attribute :>> m : MassValue;
		}
	}
	
	part def Vehicle2 {
		assert constraint { m == eng::m + trans::m }
		
		attribute m : MassValue;
		
		part eng : Engine {
			attribute :>> m : MassValue;
		}
		
		part trans : Transmission {
			attribute :>> m : MassValue;
		}
	}
	
	constraint def MassConstraint3 (
		totalMass : MassValue, 
		partMasses : MassValue[0..*]) {
			
		totalMass == sum(partMasses)
	}
	
	part def Vehicle3 {
		assert constraint massConstraint : MassConstraint3 (
			totalMass = m, 
			partMasses = {eng::m, trans::m}
		);
		
		attribute m : MassValue;
		
		part eng {
			attribute m : MassValue;
		}
		
		part trans {
			attribute m : MassValue;
		}
	}
	
	constraint def MassConstraint4 (
		totalMass : MassValue, 
		partMasses : MassValue[0..*]);
	
	constraint mc : MassConstraint4 (
		totalMass : MassValue, 
		partMasses : MassValue[0..*]) {
		
		totalMass == sum(partMasses)
	}
	
	part def Vehicle4 {
		assert mc (
			totalMass = m, 
			partMasses = {eng::m, trans::m}
		);
		
		attribute m : MassValue;
		
		part eng : Engine {
			attribute :>> m : MassValue;
		}
		
		part trans : Transmission {
			attribute :>> m : MassValue;
		}
	}
	
	constraint def MassLimit (
		mass : MassValue, 
		maxMass : MassValue) {
			
		mass <= maxMass
	}
	
	part def Vehicle5 {
		assert constraint ml : MassLimit (
			mass = m, 
			maxMass = 2500@[kg]
		);
		
		attribute m : MassValue = eng::m + trans::m;
		
		part eng : Engine {
			attribute :>> m : MassValue;
		}
		
		part trans : Transmission {
			attribute :>> m : MassValue;
		}
	}	
	
}
# Out:
# Package MassConstraintExample (d5c988ae-ecda-44bf-9280-5bf08e0c8242)

# %%
%viz --style="COMPTREE" --view="Default" "MassConstraintExample"

# %%
%viz --style="COMPTREE" --view="Tree" "MassConstraintExample"

# %%
%viz --style="COMPTREE" --view="State" "MassConstraintExample"

# %%
%viz --style="COMPTREE" --view="Interconnection" "MassConstraintExample"

# %%
%viz --style="COMPTREE" --view="Action" "MassConstraintExample"

# %%
%viz --style="COMPTREE" --view="Sequence" "MassConstraintExample"

# %%
%viz --style="COMPTREE" --view="MIXED" "MassConstraintExample"

# %%
%viz --style="POLYLINE" --view="Default" "MassConstraintExample"

# %%
%viz --style="POLYLINE" --view="Tree" "MassConstraintExample"

# %%
%viz --style="POLYLINE" --view="State" "MassConstraintExample"

# %%
%viz --style="POLYLINE" --view="Interconnection" "MassConstraintExample"

# %%
%viz --style="POLYLINE" --view="Action" "MassConstraintExample"

# %%
%viz --style="POLYLINE" --view="Sequence" "MassConstraintExample"

# %%
%viz --style="POLYLINE" --view="MIXED" "MassConstraintExample"

# %%
%viz --style="LR" --view="Default" "MassConstraintExample"

# %%
%viz --style="LR" --view="Tree" "MassConstraintExample"

# %%
%viz --style="LR" --view="State" "MassConstraintExample"

# %%
%viz --style="LR" --view="Interconnection" "MassConstraintExample"

# %%
%viz --style="LR" --view="Action" "MassConstraintExample"

# %%
%viz --style="LR" --view="Sequence" "MassConstraintExample"

# %%
%viz --style="LR" --view="MIXED" "MassConstraintExample"

# %%
%viz --style="STDCOLOR" --view="Default" "MassConstraintExample"

# %%
%viz --style="STDCOLOR" --view="Tree" "MassConstraintExample"

# %%
%viz --style="STDCOLOR" --view="State" "MassConstraintExample"

# %%
%viz --style="STDCOLOR" --view="Interconnection" "MassConstraintExample"

# %%
%viz --style="STDCOLOR" --view="Action" "MassConstraintExample"

# %%
%viz --style="STDCOLOR" --view="Sequence" "MassConstraintExample"

# %%
%viz --style="STDCOLOR" --view="MIXED" "MassConstraintExample"

# %%
%viz --style="PLANTUML" --view="Default" "MassConstraintExample"

# %%
%viz --style="PLANTUML" --view="Tree" "MassConstraintExample"

# %%
%viz --style="PLANTUML" --view="State" "MassConstraintExample"

# %%
%viz --style="PLANTUML" --view="Interconnection" "MassConstraintExample"

# %%
%viz --style="PLANTUML" --view="Action" "MassConstraintExample"

# %%
%viz --style="PLANTUML" --view="Sequence" "MassConstraintExample"

# %%
%viz --style="PLANTUML" --view="MIXED" "MassConstraintExample"

# %%
%viz --style="DEFAULT" --view="Default" "MassConstraintExample"

# %%
%viz --style="DEFAULT" --view="Tree" "MassConstraintExample"

# %%
%viz --style="DEFAULT" --view="State" "MassConstraintExample"

# %%
%viz --style="DEFAULT" --view="Interconnection" "MassConstraintExample"

# %%
%viz --style="DEFAULT" --view="Action" "MassConstraintExample"

# %%
%viz --style="DEFAULT" --view="Sequence" "MassConstraintExample"

# %%
%viz --style="DEFAULT" --view="MIXED" "MassConstraintExample"

# %%
%viz --style="TB" --view="Default" "MassConstraintExample"

# %%
%viz --style="TB" --view="Tree" "MassConstraintExample"

# %%
%viz --style="TB" --view="State" "MassConstraintExample"

# %%
%viz --style="TB" --view="Interconnection" "MassConstraintExample"

# %%
%viz --style="TB" --view="Action" "MassConstraintExample"

# %%
%viz --style="TB" --view="Sequence" "MassConstraintExample"

# %%
%viz --style="TB" --view="MIXED" "MassConstraintExample"

# %%
%viz --style="ORTHOLINE" --view="Default" "MassConstraintExample"

# %%
%viz --style="ORTHOLINE" --view="Tree" "MassConstraintExample"

# %%
%viz --style="ORTHOLINE" --view="State" "MassConstraintExample"

# %%
%viz --style="ORTHOLINE" --view="Interconnection" "MassConstraintExample"

# %%
%viz --style="ORTHOLINE" --view="Action" "MassConstraintExample"

# %%
%viz --style="ORTHOLINE" --view="Sequence" "MassConstraintExample"

# %%
%viz --style="ORTHOLINE" --view="MIXED" "MassConstraintExample"
