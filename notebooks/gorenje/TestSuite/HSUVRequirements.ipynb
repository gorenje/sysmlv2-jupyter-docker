# %% [markdown]
# # SysML v2 Test Suite
#
# This can notebook can be cleared using menu `Edit --> Clear All Outputs` and then all cells can be
# run using menu `Run --> Run All Cells`.
#
# **WARNING**: This file is generated, all modifications here will be ignored.

# %% [markdown]
# ## File: ../../sysml/src/examples/Requirements Examples/HSUVRequirements.sysml

# %%
package HSUVRequirements {
	import Requirements::*;
	
	requirement id 'UR1.1' Load: FunctionalRequirementCheck {
		// The following requirements are composite sub-requirements.
		requirement Passengers;
		requirement FuelCapacity;
		requirement Cargo;
	}
	
	requirement id 'UR1.2' EcoFriendliness: PerformanceRequirementCheck {
		requirement id 'URI1.2.1' Emissions: PerformanceRequirementCheck {
			/* The car shall meet 2010 Kyoto Accord emissions standards. */
		}
	}
	
	requirement id 'UR1.3' Performance: PerformanceRequirementCheck {
		requirement Acceleration;
		requirement id 'UR1.3.1' FuelEconomy: PerformanceRequirementCheck {
			/* User shall obtain fuel economy better than that provided by
			 * 95% of cars built in 2004.
			 */
		}
		requirement Braking;
		requirement Range;
		requirement Power;
	}
	
	requirement id 'UR1.4' Ergonomics;
	
	// Syntactically, should this be explicitly marked as a "group"?
	requirement HybridSUVSpec {		
		// The following requirements are required by reference.
		require Load;
		require EcoFriendliness;
		require Performance;
		require Ergonomics;
	}
}
# Out:
# Package HSUVRequirements (d205b89a-838b-4d53-b08a-be4c6fd845b9)

# %%
%viz --style="COMPTREE" --view="Default" "HSUVRequirements"

# %%
%viz --style="COMPTREE" --view="Tree" "HSUVRequirements"

# %%
%viz --style="COMPTREE" --view="State" "HSUVRequirements"

# %%
%viz --style="COMPTREE" --view="Interconnection" "HSUVRequirements"

# %%
%viz --style="COMPTREE" --view="Action" "HSUVRequirements"

# %%
%viz --style="COMPTREE" --view="Sequence" "HSUVRequirements"

# %%
%viz --style="COMPTREE" --view="MIXED" "HSUVRequirements"

# %%
%viz --style="POLYLINE" --view="Default" "HSUVRequirements"

# %%
%viz --style="POLYLINE" --view="Tree" "HSUVRequirements"

# %%
%viz --style="POLYLINE" --view="State" "HSUVRequirements"

# %%
%viz --style="POLYLINE" --view="Interconnection" "HSUVRequirements"

# %%
%viz --style="POLYLINE" --view="Action" "HSUVRequirements"

# %%
%viz --style="POLYLINE" --view="Sequence" "HSUVRequirements"

# %%
%viz --style="POLYLINE" --view="MIXED" "HSUVRequirements"

# %%
%viz --style="LR" --view="Default" "HSUVRequirements"

# %%
%viz --style="LR" --view="Tree" "HSUVRequirements"

# %%
%viz --style="LR" --view="State" "HSUVRequirements"

# %%
%viz --style="LR" --view="Interconnection" "HSUVRequirements"

# %%
%viz --style="LR" --view="Action" "HSUVRequirements"

# %%
%viz --style="LR" --view="Sequence" "HSUVRequirements"

# %%
%viz --style="LR" --view="MIXED" "HSUVRequirements"

# %%
%viz --style="STDCOLOR" --view="Default" "HSUVRequirements"

# %%
%viz --style="STDCOLOR" --view="Tree" "HSUVRequirements"

# %%
%viz --style="STDCOLOR" --view="State" "HSUVRequirements"

# %%
%viz --style="STDCOLOR" --view="Interconnection" "HSUVRequirements"

# %%
%viz --style="STDCOLOR" --view="Action" "HSUVRequirements"

# %%
%viz --style="STDCOLOR" --view="Sequence" "HSUVRequirements"

# %%
%viz --style="STDCOLOR" --view="MIXED" "HSUVRequirements"

# %%
%viz --style="PLANTUML" --view="Default" "HSUVRequirements"

# %%
%viz --style="PLANTUML" --view="Tree" "HSUVRequirements"

# %%
%viz --style="PLANTUML" --view="State" "HSUVRequirements"

# %%
%viz --style="PLANTUML" --view="Interconnection" "HSUVRequirements"

# %%
%viz --style="PLANTUML" --view="Action" "HSUVRequirements"

# %%
%viz --style="PLANTUML" --view="Sequence" "HSUVRequirements"

# %%
%viz --style="PLANTUML" --view="MIXED" "HSUVRequirements"

# %%
%viz --style="DEFAULT" --view="Default" "HSUVRequirements"

# %%
%viz --style="DEFAULT" --view="Tree" "HSUVRequirements"

# %%
%viz --style="DEFAULT" --view="State" "HSUVRequirements"

# %%
%viz --style="DEFAULT" --view="Interconnection" "HSUVRequirements"

# %%
%viz --style="DEFAULT" --view="Action" "HSUVRequirements"

# %%
%viz --style="DEFAULT" --view="Sequence" "HSUVRequirements"

# %%
%viz --style="DEFAULT" --view="MIXED" "HSUVRequirements"

# %%
%viz --style="TB" --view="Default" "HSUVRequirements"

# %%
%viz --style="TB" --view="Tree" "HSUVRequirements"

# %%
%viz --style="TB" --view="State" "HSUVRequirements"

# %%
%viz --style="TB" --view="Interconnection" "HSUVRequirements"

# %%
%viz --style="TB" --view="Action" "HSUVRequirements"

# %%
%viz --style="TB" --view="Sequence" "HSUVRequirements"

# %%
%viz --style="TB" --view="MIXED" "HSUVRequirements"

# %%
%viz --style="ORTHOLINE" --view="Default" "HSUVRequirements"

# %%
%viz --style="ORTHOLINE" --view="Tree" "HSUVRequirements"

# %%
%viz --style="ORTHOLINE" --view="State" "HSUVRequirements"

# %%
%viz --style="ORTHOLINE" --view="Interconnection" "HSUVRequirements"

# %%
%viz --style="ORTHOLINE" --view="Action" "HSUVRequirements"

# %%
%viz --style="ORTHOLINE" --view="Sequence" "HSUVRequirements"

# %%
%viz --style="ORTHOLINE" --view="MIXED" "HSUVRequirements"
