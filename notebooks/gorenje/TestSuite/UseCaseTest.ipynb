# %% [markdown]
# # SysML v2 Test Suite
#
# This can notebook can be cleared using menu `Edit --> Clear All Outputs` and then all cells can be
# run using menu `Run --> Run All Cells`.
#
# **WARNING**: This file is generated, all modifications here will be ignored.

# %% [markdown]
# ## File: ../../sysml/src/examples/Simple Tests/UseCaseTest.sysml

# %%
package UseCaseTest {

	part def System;	
	part def User;
	
	use case def UseSystem {
		subject system : System;
		actor user : User;
		
		objective  { 
			/* Goal */
		}
		
		include use case uc1 : UC1;	
		include use case uc2 {
			subject = system;
			actor user = UseSystem::user;
		}
	}
	
	use case def UC1;
	
	part user : User;
	
	use case uc2 {
		actor :>> user;
	}
	
	use case u : UseSystem;
	
	part system : System {
		include uc2;
		perform u;
	}
	
}
# Out:
# Package UseCaseTest (69834104-b9af-4e6e-86d5-d1b31887d1ae)

# %%
%viz --style="COMPTREE" --view="Default" "UseCaseTest"

# %%
%viz --style="COMPTREE" --view="Tree" "UseCaseTest"

# %%
%viz --style="COMPTREE" --view="State" "UseCaseTest"

# %%
%viz --style="COMPTREE" --view="Interconnection" "UseCaseTest"

# %%
%viz --style="COMPTREE" --view="Action" "UseCaseTest"

# %%
%viz --style="COMPTREE" --view="Sequence" "UseCaseTest"

# %%
%viz --style="COMPTREE" --view="MIXED" "UseCaseTest"

# %%
%viz --style="POLYLINE" --view="Default" "UseCaseTest"

# %%
%viz --style="POLYLINE" --view="Tree" "UseCaseTest"

# %%
%viz --style="POLYLINE" --view="State" "UseCaseTest"

# %%
%viz --style="POLYLINE" --view="Interconnection" "UseCaseTest"

# %%
%viz --style="POLYLINE" --view="Action" "UseCaseTest"

# %%
%viz --style="POLYLINE" --view="Sequence" "UseCaseTest"

# %%
%viz --style="POLYLINE" --view="MIXED" "UseCaseTest"

# %%
%viz --style="LR" --view="Default" "UseCaseTest"

# %%
%viz --style="LR" --view="Tree" "UseCaseTest"

# %%
%viz --style="LR" --view="State" "UseCaseTest"

# %%
%viz --style="LR" --view="Interconnection" "UseCaseTest"

# %%
%viz --style="LR" --view="Action" "UseCaseTest"

# %%
%viz --style="LR" --view="Sequence" "UseCaseTest"

# %%
%viz --style="LR" --view="MIXED" "UseCaseTest"

# %%
%viz --style="STDCOLOR" --view="Default" "UseCaseTest"

# %%
%viz --style="STDCOLOR" --view="Tree" "UseCaseTest"

# %%
%viz --style="STDCOLOR" --view="State" "UseCaseTest"

# %%
%viz --style="STDCOLOR" --view="Interconnection" "UseCaseTest"

# %%
%viz --style="STDCOLOR" --view="Action" "UseCaseTest"

# %%
%viz --style="STDCOLOR" --view="Sequence" "UseCaseTest"

# %%
%viz --style="STDCOLOR" --view="MIXED" "UseCaseTest"

# %%
%viz --style="PLANTUML" --view="Default" "UseCaseTest"

# %%
%viz --style="PLANTUML" --view="Tree" "UseCaseTest"

# %%
%viz --style="PLANTUML" --view="State" "UseCaseTest"

# %%
%viz --style="PLANTUML" --view="Interconnection" "UseCaseTest"

# %%
%viz --style="PLANTUML" --view="Action" "UseCaseTest"

# %%
%viz --style="PLANTUML" --view="Sequence" "UseCaseTest"

# %%
%viz --style="PLANTUML" --view="MIXED" "UseCaseTest"

# %%
%viz --style="DEFAULT" --view="Default" "UseCaseTest"

# %%
%viz --style="DEFAULT" --view="Tree" "UseCaseTest"

# %%
%viz --style="DEFAULT" --view="State" "UseCaseTest"

# %%
%viz --style="DEFAULT" --view="Interconnection" "UseCaseTest"

# %%
%viz --style="DEFAULT" --view="Action" "UseCaseTest"

# %%
%viz --style="DEFAULT" --view="Sequence" "UseCaseTest"

# %%
%viz --style="DEFAULT" --view="MIXED" "UseCaseTest"

# %%
%viz --style="TB" --view="Default" "UseCaseTest"

# %%
%viz --style="TB" --view="Tree" "UseCaseTest"

# %%
%viz --style="TB" --view="State" "UseCaseTest"

# %%
%viz --style="TB" --view="Interconnection" "UseCaseTest"

# %%
%viz --style="TB" --view="Action" "UseCaseTest"

# %%
%viz --style="TB" --view="Sequence" "UseCaseTest"

# %%
%viz --style="TB" --view="MIXED" "UseCaseTest"

# %%
%viz --style="ORTHOLINE" --view="Default" "UseCaseTest"

# %%
%viz --style="ORTHOLINE" --view="Tree" "UseCaseTest"

# %%
%viz --style="ORTHOLINE" --view="State" "UseCaseTest"

# %%
%viz --style="ORTHOLINE" --view="Interconnection" "UseCaseTest"

# %%
%viz --style="ORTHOLINE" --view="Action" "UseCaseTest"

# %%
%viz --style="ORTHOLINE" --view="Sequence" "UseCaseTest"

# %%
%viz --style="ORTHOLINE" --view="MIXED" "UseCaseTest"
