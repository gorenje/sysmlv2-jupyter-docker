# %% [markdown]
# # SysML v2 Test Suite
#
# This can notebook can be cleared using menu `Edit --> Clear All Outputs` and then all cells can be
# run using menu `Run --> Run All Cells`.
#
# **WARNING**: This file is generated, all modifications here will be ignored.

# %% [markdown]
# ## File: ../../sysml/src/examples/Analysis Examples/Dynamics.sysml

# %%
package Dynamics {
	import ScalarValues::Real;
	import ISQ::*;
	
	// Function definitions
	
	calc def Power
		(in whlpwr : PowerValue, in Cd : Real, in Cf : Real, in tm : MassValue, in v : SpeedValue )
		return tp : PowerValue {
			
		whlpwr - Cd * v - Cf * tm * v
	}
	
	calc def Acceleration (dt : TimeValue, tm : MassValue, tp: PowerValue) a : AccelerationValue { 
		tp * dt * tp
	}
	
	calc def Velocity (dt : TimeValue, v0 : SpeedValue, a : AccelerationValue) v : SpeedValue = v0 + a * dt;
 	
	calc def Position (dt : TimeValue, x0 : LengthValue, v : SpeedValue) : LengthValue = x0 + v * dt;
	

	// Analysis action def
	
	action def StraightLineVehicleDynamics {
		
		in attribute dt : TimeValue;
		in attribute whlpwr : PowerValue;
		in attribute Cd : Real;
		in attribute Cf: Real;
		in attribute tm : MassValue;
		in attribute v_in : SpeedValue;
		in attribute x_in : LengthValue;
		
		out attribute a_out : AccelerationValue;
		out attribute v_out : SpeedValue;
		out attribute x_out : LengthValue;
			
		assert constraint {
			attribute tp : PowerValue;
			
			tp == Power(whlpwr, Cd, Cf, tm, v_in) &
			a_out == Acceleration(dt, tm, tp) &
			v_out == Velocity(dt, v_in, a_out) &
			x_out == Position(dt, x_in, v_in)
		}
	}
	

	// Analysis actions
	
	action dyn1 : StraightLineVehicleDynamics {
		attribute tp : PowerValue = Power(whlpwr, Cd, Cf, tm, v_in);
		
		out attribute :>> a_out : AccelerationValue = Acceleration(dt, tm, tp);
		out attribute :>> v_out : SpeedValue = Velocity(dt, v_in, a_out);
		out attribute :>> x_out : LengthValue = Position(dt, x_in, v_in);
	}	
	
	action dyn2 : StraightLineVehicleDynamics {
		calc acc : Acceleration (
			dt = dyn2::dt, 
			tm = dyn2::tm, 
			tp = Power(whlpwr, Cd, Cf, tm, v_in)
		) return a = a_out;
		
		calc vel : Velocity (
			dt = dyn2::dt, 
			v0 = dyn2::v_in, 
			a = acc::a
		) return v = v_out;
		
		calc pos : Position (
			dt = dyn2::dt, 
			x0 = dyn2::x_in, 
			v0 = vel::v
		) return x = x_out;		
	}
}
# Out:
# Package Dynamics (5ab75a91-b996-4698-9d85-fed2dd679d77)

# %%
%viz --style="COMPTREE" --view="Default" "Dynamics"

# %%
%viz --style="COMPTREE" --view="Tree" "Dynamics"

# %%
%viz --style="COMPTREE" --view="State" "Dynamics"

# %%
%viz --style="COMPTREE" --view="Interconnection" "Dynamics"

# %%
%viz --style="COMPTREE" --view="Action" "Dynamics"

# %%
%viz --style="COMPTREE" --view="Sequence" "Dynamics"

# %%
%viz --style="COMPTREE" --view="MIXED" "Dynamics"

# %%
%viz --style="POLYLINE" --view="Default" "Dynamics"

# %%
%viz --style="POLYLINE" --view="Tree" "Dynamics"

# %%
%viz --style="POLYLINE" --view="State" "Dynamics"

# %%
%viz --style="POLYLINE" --view="Interconnection" "Dynamics"

# %%
%viz --style="POLYLINE" --view="Action" "Dynamics"

# %%
%viz --style="POLYLINE" --view="Sequence" "Dynamics"

# %%
%viz --style="POLYLINE" --view="MIXED" "Dynamics"

# %%
%viz --style="LR" --view="Default" "Dynamics"

# %%
%viz --style="LR" --view="Tree" "Dynamics"

# %%
%viz --style="LR" --view="State" "Dynamics"

# %%
%viz --style="LR" --view="Interconnection" "Dynamics"

# %%
%viz --style="LR" --view="Action" "Dynamics"

# %%
%viz --style="LR" --view="Sequence" "Dynamics"

# %%
%viz --style="LR" --view="MIXED" "Dynamics"

# %%
%viz --style="STDCOLOR" --view="Default" "Dynamics"

# %%
%viz --style="STDCOLOR" --view="Tree" "Dynamics"

# %%
%viz --style="STDCOLOR" --view="State" "Dynamics"

# %%
%viz --style="STDCOLOR" --view="Interconnection" "Dynamics"

# %%
%viz --style="STDCOLOR" --view="Action" "Dynamics"

# %%
%viz --style="STDCOLOR" --view="Sequence" "Dynamics"

# %%
%viz --style="STDCOLOR" --view="MIXED" "Dynamics"

# %%
%viz --style="PLANTUML" --view="Default" "Dynamics"

# %%
%viz --style="PLANTUML" --view="Tree" "Dynamics"

# %%
%viz --style="PLANTUML" --view="State" "Dynamics"

# %%
%viz --style="PLANTUML" --view="Interconnection" "Dynamics"

# %%
%viz --style="PLANTUML" --view="Action" "Dynamics"

# %%
%viz --style="PLANTUML" --view="Sequence" "Dynamics"

# %%
%viz --style="PLANTUML" --view="MIXED" "Dynamics"

# %%
%viz --style="DEFAULT" --view="Default" "Dynamics"

# %%
%viz --style="DEFAULT" --view="Tree" "Dynamics"

# %%
%viz --style="DEFAULT" --view="State" "Dynamics"

# %%
%viz --style="DEFAULT" --view="Interconnection" "Dynamics"

# %%
%viz --style="DEFAULT" --view="Action" "Dynamics"

# %%
%viz --style="DEFAULT" --view="Sequence" "Dynamics"

# %%
%viz --style="DEFAULT" --view="MIXED" "Dynamics"

# %%
%viz --style="TB" --view="Default" "Dynamics"

# %%
%viz --style="TB" --view="Tree" "Dynamics"

# %%
%viz --style="TB" --view="State" "Dynamics"

# %%
%viz --style="TB" --view="Interconnection" "Dynamics"

# %%
%viz --style="TB" --view="Action" "Dynamics"

# %%
%viz --style="TB" --view="Sequence" "Dynamics"

# %%
%viz --style="TB" --view="MIXED" "Dynamics"

# %%
%viz --style="ORTHOLINE" --view="Default" "Dynamics"

# %%
%viz --style="ORTHOLINE" --view="Tree" "Dynamics"

# %%
%viz --style="ORTHOLINE" --view="State" "Dynamics"

# %%
%viz --style="ORTHOLINE" --view="Interconnection" "Dynamics"

# %%
%viz --style="ORTHOLINE" --view="Action" "Dynamics"

# %%
%viz --style="ORTHOLINE" --view="Sequence" "Dynamics"

# %%
%viz --style="ORTHOLINE" --view="MIXED" "Dynamics"
