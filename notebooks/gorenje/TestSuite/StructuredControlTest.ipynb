# %% [markdown]
# # SysML v2 Test Suite
#
# This can notebook can be cleared using menu `Edit --> Clear All Outputs` and then all cells can be
# run using menu `Run --> Run All Cells`.
#
# **WARNING**: This file is generated, all modifications here will be ignored.

# %% [markdown]
# ## File: ../../sysml/src/examples/Simple Tests/StructuredControlTest.sysml

# %%
package StructuredControlTest {
	
	action {
		attribute i : ScalarValues::Integer := 0;
		attribute b : ScalarValues::Boolean;
		
		if i < 0 {
			assign i := 0;
		} else if i == 0 {
			assign i := 1;
		} else {
			assign i := i + 1;
		}
		
		if i > 0 {
			assign i := i + 1;
		}
		
		then action aLoop
		while i > 0 {
			assign i := i - 1;
		} until b;
		
		then while i > 0 {
			assign i := i - 1;
		}
		
		loop {
			assign i := i - 1;
		} until b;
				
		for n : ScalarValues::Integer in (1, 2, 3) {
			assign i := i * n;
		}
	}
}
# Out:
# Package StructuredControlTest (2730aa2d-8347-41c6-b971-97dcb61e3360)

# %%
%viz --style="COMPTREE" --view="Default" "StructuredControlTest"

# %%
%viz --style="COMPTREE" --view="Tree" "StructuredControlTest"

# %%
%viz --style="COMPTREE" --view="State" "StructuredControlTest"

# %%
%viz --style="COMPTREE" --view="Interconnection" "StructuredControlTest"

# %%
%viz --style="COMPTREE" --view="Action" "StructuredControlTest"

# %%
%viz --style="COMPTREE" --view="Sequence" "StructuredControlTest"

# %%
%viz --style="COMPTREE" --view="MIXED" "StructuredControlTest"

# %%
%viz --style="POLYLINE" --view="Default" "StructuredControlTest"

# %%
%viz --style="POLYLINE" --view="Tree" "StructuredControlTest"

# %%
%viz --style="POLYLINE" --view="State" "StructuredControlTest"

# %%
%viz --style="POLYLINE" --view="Interconnection" "StructuredControlTest"

# %%
%viz --style="POLYLINE" --view="Action" "StructuredControlTest"

# %%
%viz --style="POLYLINE" --view="Sequence" "StructuredControlTest"

# %%
%viz --style="POLYLINE" --view="MIXED" "StructuredControlTest"

# %%
%viz --style="LR" --view="Default" "StructuredControlTest"

# %%
%viz --style="LR" --view="Tree" "StructuredControlTest"

# %%
%viz --style="LR" --view="State" "StructuredControlTest"

# %%
%viz --style="LR" --view="Interconnection" "StructuredControlTest"

# %%
%viz --style="LR" --view="Action" "StructuredControlTest"

# %%
%viz --style="LR" --view="Sequence" "StructuredControlTest"

# %%
%viz --style="LR" --view="MIXED" "StructuredControlTest"

# %%
%viz --style="STDCOLOR" --view="Default" "StructuredControlTest"

# %%
%viz --style="STDCOLOR" --view="Tree" "StructuredControlTest"

# %%
%viz --style="STDCOLOR" --view="State" "StructuredControlTest"

# %%
%viz --style="STDCOLOR" --view="Interconnection" "StructuredControlTest"

# %%
%viz --style="STDCOLOR" --view="Action" "StructuredControlTest"

# %%
%viz --style="STDCOLOR" --view="Sequence" "StructuredControlTest"

# %%
%viz --style="STDCOLOR" --view="MIXED" "StructuredControlTest"

# %%
%viz --style="PLANTUML" --view="Default" "StructuredControlTest"

# %%
%viz --style="PLANTUML" --view="Tree" "StructuredControlTest"

# %%
%viz --style="PLANTUML" --view="State" "StructuredControlTest"

# %%
%viz --style="PLANTUML" --view="Interconnection" "StructuredControlTest"

# %%
%viz --style="PLANTUML" --view="Action" "StructuredControlTest"

# %%
%viz --style="PLANTUML" --view="Sequence" "StructuredControlTest"

# %%
%viz --style="PLANTUML" --view="MIXED" "StructuredControlTest"

# %%
%viz --style="DEFAULT" --view="Default" "StructuredControlTest"

# %%
%viz --style="DEFAULT" --view="Tree" "StructuredControlTest"

# %%
%viz --style="DEFAULT" --view="State" "StructuredControlTest"

# %%
%viz --style="DEFAULT" --view="Interconnection" "StructuredControlTest"

# %%
%viz --style="DEFAULT" --view="Action" "StructuredControlTest"

# %%
%viz --style="DEFAULT" --view="Sequence" "StructuredControlTest"

# %%
%viz --style="DEFAULT" --view="MIXED" "StructuredControlTest"

# %%
%viz --style="TB" --view="Default" "StructuredControlTest"

# %%
%viz --style="TB" --view="Tree" "StructuredControlTest"

# %%
%viz --style="TB" --view="State" "StructuredControlTest"

# %%
%viz --style="TB" --view="Interconnection" "StructuredControlTest"

# %%
%viz --style="TB" --view="Action" "StructuredControlTest"

# %%
%viz --style="TB" --view="Sequence" "StructuredControlTest"

# %%
%viz --style="TB" --view="MIXED" "StructuredControlTest"

# %%
%viz --style="ORTHOLINE" --view="Default" "StructuredControlTest"

# %%
%viz --style="ORTHOLINE" --view="Tree" "StructuredControlTest"

# %%
%viz --style="ORTHOLINE" --view="State" "StructuredControlTest"

# %%
%viz --style="ORTHOLINE" --view="Interconnection" "StructuredControlTest"

# %%
%viz --style="ORTHOLINE" --view="Action" "StructuredControlTest"

# %%
%viz --style="ORTHOLINE" --view="Sequence" "StructuredControlTest"

# %%
%viz --style="ORTHOLINE" --view="MIXED" "StructuredControlTest"
