# %% [markdown]
# # SysML v2 Kernel Magic Commands
#
# List of the kernel magic commands.
#
# Inspired by [MBSE4u.com](https://mbse4u.com/2020/12/21/sysml-v2-release-whats-inside/).
#
# ## list
#
# [Codebase](https://github.com/Systems-Modeling/SysML-v2-Pilot-Implementation/blob/master/org.omg.sysml.jupyter.kernel/src/main/java/org/omg/sysml/jupyter/kernel/magic/Listing.java)

# %%
%list
# Out:
# Package Actions (667640ed-9f65-42d9-8e65-93b8fabb62e9)
# Package AnalysisCases (9aa4d560-f517-4288-8f1f-848f855a2517)
# Package AnalysisTooling (66a82fea-b6ee-4f25-a27e-0530c725422d)
# Package Attributes (f690d570-13df-434a-af3c-5f10a638e6e9)
# Package Base (4a4ceba0-8f59-4a78-ad2a-892f2ac68c4a)
# Package BaseFunctions (d3d224bd-aedf-4302-885a-561aed5e552b)
# Package BasicGeometry (f6d59523-4443-4d39-a455-01d87e8aee31)
# Package BooleanFunctions (ef78b869-bd24-4298-b585-a3850a880d71)
# Package Calculations (b4e7c3f2-1ebd-464a-b075-c3ec40f98e52)
# Package Cases (8a44fe7e-4fd0-4af3-970d-d34a9bc0ce63)
# Package ComplexFunctions (01bd993e-22c5-4177-bcb7-7c90b4897299)
# Package Connections (6c4cc901-76c6-4f48-957e-020f9f9fddd9)
# Package Constraints (ffa12d0e-b853-4be2-91d4-c30db1d2fc1e)
# Package ControlFunctions (731be035-4477-4cd0-a642-e38147073d08)
# Package ControlPerformances (bcf58f52-0cdc-43a1-a681-ceceb0adbe56)
# Package IntegerFunctions (1f23a501-e6a6-4a3f-bc20-b92fb53aa630)
# Package Interfaces (93943e14-1670-4d56-99a7-972a89d3bf27)
# Package ISQ (2db75ea4-4b1c-4a89-a3b4-0f991200e345)
# Package ISQAcoustics (8b62c16e-eff7-4b1a-b205-da09fbc685ea)
# Package ISQAtomicNuclear (609e4315-4913-4683-8321-af9966f6ed52)
# Package ISQCharacteristicNumbers (eda3ecad-f81b-4110-881b-1eb705b27cc5)
# Package ISQChemistryMolecular (b585a913-ad7d-4baa-95c4-b8953678e2cf)
# Package ISQElectromagnetism (981c717e-ca3f-4faa-931b-9e1f743e0ffb)
# Package ISQLight (df09a948-3483-4393-adb4-c78344017441)
# Package ISQMechanics (e3e561b6-0ba3-48c1-9e5b-7735cb4ad90b)
# Package ISQSpaceTime (48c8a22c-2219-4fda-a5cb-b3571162bdf6)
# Package ISQThermodynamics (da4f510f-4fa0-4bec-b4c0-2e3b982eaad0)
# Package Items (90662e35-a695-4a27-b872-047c21124beb)
# Package Links (bd23b21f-bf88-4dc3-b3d8-088b39bf4e03)
# Package NaturalFunctions (f16421cb-cab9-4c7b-9544-eabd29c07536)
# Package NonScalarFunctions (887cecd6-eaf8-4cfe-b4c0-d188bb003f5a)
# Package NonScalarValues (0f8c5a8b-81a5-429c-9611-5ab41f4c1c7b)
# Package NumericalFunctions (f3305236-6bb9-458f-bec7-4b3e4e12123e)
# Package Objects (559cf0d1-fec5-4ad9-a905-dd99c1e0530e)
# Package Occurrences (fd180d99-8f54-43e1-a524-a083fbaa0344)
# Package Parts (4678d050-b97a-4bd8-bc5c-568723e58aca)
# Package Performances (7e8fcb78-3cb5-435e-9800-e28bd693e67c)
# Package Ports (6d36dcba-02f2-423e-9273-c599a2569048)
# Package Quantities (57eb0b40-d790-4daf-a683-7d1ff9e556e7)
# Package QuantityCalculations (e2a10700-670b-45fc-b536-ea91a1c7ab2c)
# Package RationalFunctions (b29c3c3a-38c0-424b-8bd9-36bf4c8b6f7b)
# Package RealFunctions (a47ba10f-3813-46c1-bf69-5549d18ddb4c)
# Package Requirements (d4752a2b-06e3-41ee-95ea-4c5f96b523df)
# Package ScalarFunctions (e46539e0-48be-4391-8995-30bec250186b)
# Package ScalarValues (824f7c20-223c-4157-b9eb-11ee9f1ca0fb)
# Package SI (1d75d14e-e8e0-4a59-bf22-2ecb38f8c2c1)
# Package SIPrefixes (872d1256-92b1-4187-ba4b-e04c7094cb25)
# Package StatePerformances (e8dc56cd-31f2-4da5-9a0c-ba575d90d2bb)
# Package States (bfd9c60c-c79d-489d-81fd-6923825045ff)
# Package StateSpaceRepresentation (cc945763-26ef-4a16-93e1-5885596d8d92)
# Package StringFunctions (667b7635-4ed2-45d2-b221-584f99ae7c50)
# Package Time (aba0c30d-38f6-4219-bb73-66e22145568b)
# Package TradeStudies (b7a65c9d-7054-4787-85a1-a8a35dfa4337)
# Package Transfers (9fcfe493-d2c7-4e3c-a1da-1109e495fa8c)
# Package TransitionPerformances (d9a7b6ee-e253-4bc1-9dda-954c986629e3)
# Package UnitsAndScales (7ea96af7-4ba3-48a8-8fa3-981328a14013)
# Package UnlimitedNaturalFunctions (ac0d0d98-2866-49d5-a909-f20b441a2d08)
# Package USCustomaryUnits (06a4705e-9f6d-4596-b056-10e027a96bf4)
# Package VerificationCases (ddc3a6b1-e0cb-4b79-9704-a906c93cb287)
# Package Views (31b7f75e-7da4-45ae-b0bd-a84825374115)

# %% [markdown]
# ### Limited querying is also possible.
#
# The query string works as an ["import"](https://github.com/Systems-Modeling/SysML-v2-Pilot-Implementation/blob/0be3bc228ad3cc56bfb9c340866c2ae59a6d2601/org.omg.sysml.interactive/src/org/omg/sysml/interactive/SysMLInteractive.java#L230) statement in Sysml. That is the following is to be intrepreted as `import Objects::*;` and then show all membership. The [specs](/files/doc/2-OMG_Systems_Modeling_Language_(SysML).pdf) (page 108 of 413) provide an overview what can be passed to import.

# %%
%list "Objects::*"
# Out:
# AssociationStructure BinaryLinkObject (090e57e1-f1d5-4e22-aadb-112fdee81acb)
# Feature binaryLinkObjects (2dba0190-7b61-42d5-84f8-3e96df47d457)
# AssociationStructure LinkObject (d860be18-204f-43f3-9b44-eda27e32c779)
# Feature linkObjects (9c06a7bc-9af3-4029-b04b-d00aaa520ee7)
# Structure Object (0f2c9813-aeaa-4966-ad9d-6824e5ea278f)
# Feature objects (17da9719-aa9e-4f86-a29a-77931db14c56)

# %%
%list "Objects::**"
# Out:
# Feature $collection (aa8f3393-f5f0-4c2e-a061-ffffb8c8aef3)
# AssociationStructure BinaryLinkObject (090e57e1-f1d5-4e22-aadb-112fdee81acb)
# Feature binaryLinkObjects (2dba0190-7b61-42d5-84f8-3e96df47d457)
# Step enactedPerformances (d12d3d27-5ae7-4913-a386-d46931061a71)
# Feature incomingTransfers (f08496a9-f7a3-4b08-937d-c79ce1f9a017)
# Feature involvedObjects (c16f542e-910b-49a3-9932-0ee0c0e8ef1c)
# Step involvingPerformances (d5b33692-b4c3-4b31-bb6a-fc5fb6c20301)
# Feature isInstant (723b4eb5-e1e6-4ca5-8c16-25d8fd1345d2)
# Feature isMove (fea88214-935e-40fd-9b90-2b50eb094ee0)
# Feature isPush (e2980014-c693-4af8-8f7f-95055814cee3)
# Feature item (1cd03ba1-6ffc-45f3-8645-e71752ec2d3f)
# AssociationStructure LinkObject (d860be18-204f-43f3-9b44-eda27e32c779)
# Feature linkObjects (9c06a7bc-9af3-4029-b04b-d00aaa520ee7)
# Feature longerOccurrence (10e7f5d2-162b-44c9-b913-8624268e7ffa)
# Feature middleShots (53fdaf20-636f-4104-88e0-f48aa9acfeb4)
# Structure Object (0f2c9813-aeaa-4966-ad9d-6824e5ea278f)
# Feature objects (17da9719-aa9e-4f86-a29a-77931db14c56)
# Feature participant (1d0de559-a9b6-45c1-a884-1e331796c46d)
# Feature performers (47693ef2-7874-49d6-82ad-7e1aaaedf232)
# Feature portionOf (c16f4124-b83e-4309-a1b6-89b39543a42c)
# Feature portionOfLife (e0b3a541-9c9d-4e82-8d84-cc8aca5f9496)
# Feature portions (b53b85d5-f359-4757-a8ca-87c4da6d916e)
# Feature predecessors (403b7bfb-66fd-46e4-84ff-80df45680074)
# Feature s (58a59246-493d-4fd6-8dc3-e253f9fc1e9c)
# Feature shorterOccurrence (302a86a5-94ec-4193-a815-335d5777e229)
# Feature snapshotOf (00960d41-ff4e-4e55-a9f8-ac4a31bfa824)
# Feature snapshots (b7f2371c-5498-45e2-86d5-374393c95566)
# Feature sourceOutput (e9cb7a46-7efd-4290-8bfb-5e5b0a55e59e)
# AssociationStructure SourceOutputLink (50cfdca1-3c90-4c0e-9d1c-b25020f718f4)
# Connector sourceOutputLink (4d1c98d0-b202-4cdd-950d-26ea420a69d9)
# BlockExpression subBooleanEvaluations (cb0814d5-6c32-458b-9d3e-db254e93ee6e)
# BlockExpression subevaluations (f4e0f437-030f-45ee-9e61-ea7bea92730d)
# Step subflows (eda1d7f1-b1c8-409f-bf78-2e24036c9f16)
# Feature suboccurrences (3be76669-b838-4ed1-bbfe-032565d6c900)
# Step subperformances (4a2f5bbb-4fc1-48b4-88bf-62bdbf0043d4)
# Step subtransfers (bc11c9a5-94be-4f1e-a8e8-38fd15141070)
# Feature successors (e938c4f2-9004-4fcc-8d35-dab85aece158)
# Feature targetInput (b4a417d3-2a48-46c5-ac73-81e3ea8ec3a5)
# AssociationStructure TargetInputLink (501b3c6e-0d86-4f9c-96aa-41912a77bab7)
# Connector targetInputLink (d4adc4c2-ce8a-413e-b55f-04eb77bdbe98)
# Feature timeSliceOf (b6c746a0-fb27-466d-afc1-de80eab1bdad)
# Feature timeSlices (cc139611-b0a9-4609-a572-76c1e6fe3836)

# %% [markdown]
# ## viz
#
# Graphviz'ify elements from the model.
#
# [Codebase](https://github.com/Systems-Modeling/SysML-v2-Pilot-Implementation/blob/master/org.omg.sysml.jupyter.kernel/src/main/java/org/omg/sysml/jupyter/kernel/magic/Viz.java) and [Kernel Code](https://github.com/Systems-Modeling/SysML-v2-Pilot-Implementation/blob/0be3bc228ad3cc56bfb9c340866c2ae59a6d2601/org.omg.sysml.interactive/src/org/omg/sysml/interactive/SysMLInteractive.java#L283-L316)

# %%
%viz "Views"

# %%
%viz "Objects" --style="PLANTUML"

# %% [markdown]
# ### Arguments to %viz
#
# - style : COMPTREE, POLYLINE, LR, STDCOLOR, PLANTUML, DEFAULT, TB, ORTHOLINE
# - view : Default Tree State Interconnection Action Sequence MIXED

# %%
%viz "Objects" --view=State --style="PLANTUML"

# %% [markdown]
# ### %viz Hidden Option
#
# There is also a hidden style option: `PUMLCODE` to get the original plant UML code of the diagram.

# %%
%viz --style=PUMLCODE Views
# Out:
# @startuml
# skinparam monochrome true
# skinparam classbackgroundcolor white
# skinparam shadowing false
# skinparam wrapWidth 300
# hide circle
#
# note as E1
# [[psysml:5f8b4834-e9b0-4a28-9777-23b90ec83f83 @]]Ports that are on this Part.
#
# end note
# rec usage "exhibitedStates" as E3 [[psysml:fecd366b-d15e-4f48-a144-f95500a0adcc ]] {
# }
#
# note as E2
# [[psysml:d6e8c5dd-8092-448c-9a64-0641ec6874dc @]]Actions that are performed by this Part.
#
# end note
# note as E4
# [[psysml:e455dab1-8ad8-40cf-bd7b-099dc67715dd @]]States that are exhibited by this Part.
#
# end note
# E4 .. E3 [[psysml:e455dab1-8ad8-40cf-bd7b-099dc67715dd ]]
# note as E5
# [[psysml:c159d7a6-87c3-4f19-8717-2ed2955a5168 @]]Note: assumptions and constraints are redefined here solely to simplify the
# resolution of their qualified names as library elements.
#
# end note
# note as E6
# [[psysml:a10f2113-46f8-4f2a-bdfb-4325a802d07d @]]The entity that is being checked for satisfaction of the required constraints.
#
# end note
# note as E7
# [[psysml:b1d03383-edb8-4030-a379-a2f541dc3105 @]]Nested requirements, which are also required constraints.
#
# end note
# note as E8
# [[psysml:1c798c49-8357-4ebc-9db0-cbf21cc433c2 @]]Other Views that are used in the rendering of this View.
#
# end note
# note as E9
# [[psysml:c5a72a18-3af9-4842-ab46-e50a171352e9 @]]ViewpointCheck is a RequirementCheck for checking if a View meets the concerns of viewpoint stakeholders.
# It is the base type of all ViewpointDefinitions.
#
# end note
# note as E10
# [[psysml:5b089ffd-8023-43f4-a937-f6d50ed03856 @]]Other Renderings used to carry out this Rendering.
#
# end note
# note as E11
# [[psysml:65f9b23a-d6a4-4f67-ac86-e06efe3bd109 @]]Rendering is the base type of all RenderingDefinitions.
#
# end note
# note as E12
# [[psysml:952efa67-d791-4a38-8f15-820a3b5e2646 @]]views is the base feature of all ViewUsages.
#
# end note
# note as E13
# [[psysml:9e48fa44-ec99-4ee0-a826-d5ca68b12a26 @]]viewpointChecks is the base feature of all ViewpointUsages.
#
# end note
# note as E14
# [[psysml:0b8d7aca-0e57-4f32-bc47-56e39480abab @]]renderings is the base feature of all RenderingUsages.
#
# end note
# @enduml

# %% [markdown]
# ## publish
#
# Push models to publish the model to a SysML v2 repository server.
#
# [Codebase](https://github.com/Systems-Modeling/SysML-v2-Pilot-Implementation/blob/master/org.omg.sysml.jupyter.kernel/src/main/java/org/omg/sysml/jupyter/kernel/magic/Publish.java)

# %%
%publish "Links"
# Out:
# ERROR:'Links' is a library element

# %% [markdown]
# So library elements can't be published, so we'll create a package and publish that.
#
# Package take from [MBSE4U Notebook](https://nbviewer.jupyter.org/github/MBSE4U/SysMLv2JupyterBook/blob/master/SysMLv2JupyterBook.ipynb).

# %%
package eVehicle_LogicalArchitecture_v1 {
    part eVehicle {    
        part body;
        part battery;
        part engine;
        part frontAxis;
        part rearAxis;
        part frontWheel[2];
        part rearWheel[2];
    }
}
# Out:
# Package eVehicle_LogicalArchitecture_v1 (255aefb9-361a-450a-af04-ece68639c23f)

# %%
%publish eVehicle_LogicalArchitecture_v1
# Out:
# API base path: http://sysml2.intercax.com:9000
# Processing
# Posting Commit (29 elements)...a3e53103-726c-42ee-bf04-99e6dbe45591
# Saved to Project eVehicle_LogicalArchitecture_v1 Sat Mar 13 13:42:24 UTC 2021 (91c54965-bbcf-41e5-b979-8e612808d1f0)

# %% [markdown]
# **Viewing Projects**
#
# Once the model has been published, we can view our stored [project](http://localhost:9000/projects) in the API server.

# %% [markdown]
# ## show
#
# Which gives a textual outline of the Model.
#
# [Codebase](https://github.com/Systems-Modeling/SysML-v2-Pilot-Implementation/blob/master/org.omg.sysml.jupyter.kernel/src/main/java/org/omg/sysml/jupyter/kernel/magic/Show.java)

# %%
%show Objects
# Out:
# Package Objects (559cf0d1-fec5-4ad9-a905-dd99c1e0530e)
#   [Import] Package Links (bd23b21f-bf88-4dc3-b3d8-088b39bf4e03)
#   [Membership Anything] Classifier Anything (14e640e1-3603-4ed2-a029-bc7f6b4132b8)
#   [Membership things] Feature things (5ba04ec4-f974-45ca-89f2-e3e0e4eebb10)
#   [Membership Occurrence] Class Occurrence (3a3eeec5-ca24-47b4-aa51-ca5274683535)
#   [Membership Performance] Behavior Performance (6947a872-8243-4e69-aa62-2116f0a5d15f)
#   [Membership performances] Step performances (81a3a827-3b1a-47e6-947f-79636b1b88de)
#   [Membership] Structure Object (0f2c9813-aeaa-4966-ad9d-6824e5ea278f)
#     [Superclassing] Class Occurrence (3a3eeec5-ca24-47b4-aa51-ca5274683535)
#     [FeatureMembership] Feature self (a9fd11ab-8c89-4b07-9dd1-3b3ba10d0496)
#       [FeatureTyping] Structure Object (0f2c9813-aeaa-4966-ad9d-6824e5ea278f)
#       [Redefinition] Feature self (50cce8f1-5fbc-44f6-a271-bb95078b0866)
#     [FeatureMembership] Step involvingPerformances (d5b33692-b4c3-4b31-bb6a-fc5fb6c20301)
#       [FeatureTyping] Behavior Performance (6947a872-8243-4e69-aa62-2116f0a5d15f)
#       [Subsetting] Step performances (81a3a827-3b1a-47e6-947f-79636b1b88de)
#       [Membership] MultiplicityRange (965a0e24-a56a-4817-8a19-ee68ca06a004)
#         [Subsetting (implicit)] Feature naturals (8d4629a8-38f0-40cc-9bd3-c541cbcb3485)
#         [Membership] LiteralInteger (9e3227c9-7de7-40b8-8184-80cdea1b9a72)
#           [ReturnParameterMembership] Feature $result (91103ff6-c439-4b81-bba7-62f1cf45b60e)
#         [Membership] LiteralUnbounded (3a669ef3-26a1-4f2d-aa8e-21ff47f50b4b)
